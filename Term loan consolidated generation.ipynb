# %%
import pandas as pd
import numpy as np
import warnings
import time
from datetime import datetime, timedelta, date
warnings.filterwarnings('ignore')
import os
pd.options.display.max_columns = 500
pd.options.display.max_rows = 500
from dateutil.relativedelta import relativedelta
from numpy import concatenate as cct
import glob

# %%
import openpyxl

# %%
path = os.getcwd()

# %%
path
# Out:
# 'C:\\Users\\Tithi Hunka\\OneDrive - Pine Labs Private Limited\\TermLoans Code_Dummy'

# %%
df_lendingkart = pd.read_csv(path+'\\LK\\LK.csv')

# %%
df_lendingkart.head()
# Out:
#   application_id    leadid     cls_app_id                        email_id  \
# 0  LAI-119474475  32601936  LAI-119474475  maimunaenterprisesog@gmail.com
# 1  LAI-120459002  34049322  LAI-120459002       akashingole8007@gmail.com
# 2  LAI-120537585  34159809  LAI-120537585    saurabhagrawal7090@gmail.com
# 3  LAI-120007964  33422247  LAI-120007964           nhusain7371@gmail.com
# 4  LAI-120477620  34077524  LAI-120477620     ranvijaysingh2324@gmail.com
#
#    mobile_number        created_by  SubDSA Details      customer_name  \
# 0   9.822534e+09   PineLabs_Direct             NaN          Izhar Ali
# 1   8.007892e+09   PineLabs_Direct             NaN       Akash Ingole
# 2   7.895085e+09   PineLabs_Direct             NaN    Saurabh Agrawal
# 3   8.896487e+09  Abhijeet Rathore             NaN  Mohd Nasir Husain
# 4   8.630255e+09   PineLabs_Direct             NaN     Ranvijay Singh
#
#                   unique_id app_created_date app_modified_date  \
# 0  64ea0ad754f900985d5290d7       26-08-2023        11-11-2023
# 1  6543b0a453a8c4c16c68c8b5       05-11-2023        11-11-2023
# 2  654e537127c67e891e499323       10-11-2023        11-11-2023
# 3                       NaN       09-10-2023        11-11-2023
# 4                       NaN       06-11-2023        11-11-2023
#
#        lead_source      created_by.1         company_name regitration_type  \
# 0  PineLabs_Direct   PineLabs_Direct  MAIMUNA ENTERPRISES   Proprietorship
# 1  PineLabs_Direct   PineLabs_Direct        HOTEL MARATHA   Proprietorship
# 2  PineLabs_Direct   PineLabs_Direct         M.S.FASHIONS   Proprietorship
# 3  PineLabs_Direct  Abhijeet Rathore   M/S HUSAIN TELECOM   Proprietorship
# 4  PineLabs_Direct   PineLabs_Direct                  NaN   Proprietorship
#
#                                  industry   pincode        city  \
# 0       White goods-Electronic Appliances  440018.0      NAGPUR
# 1                Restaurant & Hospitality  431001.0  AURANGABAD
# 2         Apparels;Clothing & Accessories  302004.0      JAIPUR
# 3  Computers;Mobile & related Accessories  272175.0  KHALILABAD
# 4       White goods-Electronic Appliances       NaN         NaN
#
#            state       revenuerange    age_of_business delivery_method  \
# 0    MAHARASHTRA      1 - 10 Crores  More than 5 Years         Regular
# 1    MAHARASHTRA      1 - 10 Crores  More than 5 Years         Pending
# 2      RAJASTHAN       12 - 30 Lacs  More than 5 Years         Pending
# 3  UTTAR PRADESH  60 Lacs - 1 Crore       1 to 5 Years         Pending
# 4            NaN       30 - 60 Lacs       1 to 5 Years         Regular
#
#   application_type product_type  desired_amount cibil_status  \
# 0              New    Term Loan          750000     ACCEPTED
# 1              New    Term Loan         1500000     ACCEPTED
# 2              New    Term Loan          100000     ACCEPTED
# 3              New    Term Loan               0     ACCEPTED
# 4              New    Term Loan               0     ACCEPTED
#
#                     Status                       Substatus  \
# 0                Disbursed                       Disbursed
# 1                Disbursed                       Disbursed
# 2  Application in Progress  Application Details Incomplete
# 3     Application Rejected                Reject - Expired
# 4     Application Rejected                   Reject - Lead
#
#              Rejection_reason terms_sent_date  terms_amount  interest_rate  \
# 0                         NaN      08-11-2023      988000.0           1.45
# 1                         NaN      10-11-2023      418000.0           1.40
# 2                         NaN             NaN           NaN            NaN
# 3  Application Expired-Dedupe             NaN           NaN            NaN
# 4     Not Registered Business             NaN           NaN            NaN
#
#   interest_rate_type  terms_tenure  processing_fess           insurer_name  \
# 0               Flat          36.0          51058.0  ICICI-Income Suraksha
# 1               Flat          36.0          23328.0  ICICI-Income Suraksha
# 2                NaN           NaN              NaN                    NaN
# 3                NaN           NaN              NaN                    NaN
# 4                NaN           NaN              NaN                    NaN
#
#    insurance_amount  loan_amount FI_Status  FI_Substatus acceptance_status  \
# 0           30762.0     988000.0       NaN           NaN         Disbursed
# 1           13916.0     418000.0       NaN           NaN         Disbursed
# 2               NaN          NaN       NaN           NaN               NaN
# 3               NaN          NaN       NaN           NaN               NaN
# 4               NaN          NaN       NaN           NaN               NaN
#
#   acceptance_reason risk_status agreement_generated_date agreement_sent_date  \
# 0               NaN    Approved               09-11-2023                 NaN
# 1               NaN    Approved               11-11-2023                 NaN
# 2               NaN         NaN                      NaN                 NaN
# 3               NaN         NaN                      NaN                 NaN
# 4               NaN         NaN                      NaN                 NaN
#
#   agreement_status agreement_sent_by  courier_company_name disbursal_date  \
# 0        Disbursed               NaN                   NaN     11-11-2023
# 1        Disbursed               NaN                   NaN     11-11-2023
# 2              NaN               NaN                   NaN            NaN
# 3              NaN               NaN                   NaN            NaN
# 4              NaN               NaN                   NaN            NaN
#
#    disbursed_interest_rate  disbursed_amount  disbursed_tenure  \
# 0                     17.4          988000.0              36.0
# 1                     16.8          418000.0              36.0
# 2                      NaN               NaN               NaN
# 3                      NaN               NaN               NaN
# 4                      NaN               NaN               NaN
#
#   first_installment_date
# 0             15-12-2023
# 1             15-12-2023
# 2                    NaN
# 3                    NaN
# 4                    NaN

# %%
df_lendingkart['app_created_date'] = df_lendingkart['app_created_date'].str.slice(6,10)+'-'+df_lendingkart['app_created_date'].str.slice(3,5)+'-'+df_lendingkart['app_created_date'].str.slice(0,2)

# %%
df_lendingkart['disbursal_date'] = df_lendingkart['disbursal_date'].str.slice(6,10)+'-'+df_lendingkart['disbursal_date'].str.slice(3,5)+'-'+df_lendingkart['disbursal_date'].str.slice(0,2)

# %%
df_lendingkart['terms_sent_date'] = df_lendingkart['terms_sent_date'].str.slice(6,10)+'-'+df_lendingkart['terms_sent_date'].str.slice(3,5)+'-'+df_lendingkart['terms_sent_date'].str.slice(0,2)

# %%
df_lendingkart['app_created_date'].dtype
# Out:
# dtype('O')

# %%
df_lendingkart['disbursal_date'].dtype
# Out:
# dtype('O')

# %%
df_lendingkart.sample(5)
# Out:
#      application_id    leadid     cls_app_id                        email_id  \
# 3827  LAI-121675017  35943455  LAI-121675017          vkadiwala229@gmail.com
# 1156  LAI-120525375  34143539  LAI-120525375      naveenjuneja2121@gmail.com
# 3038  LAI-117860949  29972726  LAI-117860949        pummytelecom58@gmail.com
# 3615  LAI-121523117  35722893  LAI-121523117         bhatisahil455@gmail.com
# 3325  LAI-119108341  31994941  LAI-119108341  narayandaschabra1985@gmail.com
#
#       mobile_number       created_by  SubDSA Details   customer_name  \
# 3827   9.033253e+09  PineLabs_Direct             NaN    Saddam meman
# 1156   9.914392e+09  PineLabs_Direct             NaN    Naveen Kumar
# 3038   9.999980e+09  PineLabs_Direct             NaN   Sandeep Kumar
# 3615   9.667473e+09  PineLabs_Direct             NaN   Sahil Rangreg
# 3325   7.999111e+09  PineLabs_Direct             NaN  Narayan Chabra
#
#                      unique_id app_created_date app_modified_date  \
# 3827  65c39048c30ec1bd8443f48b       2024-02-07        07-02-2024
# 1156  6521f8772278cbddbfb5e5bd       2023-11-09        11-12-2023
# 3038                       NaN       2023-05-08        20-01-2024
# 3615  64c35bfa40d07751c2436174       2024-01-27        03-02-2024
# 3325  64c5270840d07751c243a8ab       2023-07-29        28-01-2024
#
#           lead_source     created_by.1               company_name  \
# 3827  PineLabs_Direct  PineLabs_Direct  PERFECT SALES CORPORATION
# 1156  PineLabs_Direct  PineLabs_Direct     M/S VASDEV CYCLE WORKS
# 3038  PineLabs_Direct  PineLabs_Direct              PUMMY TELECOM
# 3615  PineLabs_Direct  PineLabs_Direct              SAHIL RANGREJ
# 3325  PineLabs_Direct  PineLabs_Direct                        NaN
#
#      regitration_type                                industry   pincode  \
# 3827   Proprietorship                                     NaN  383001.0
# 1156   Proprietorship         Industrial Supplies & Solutions  140501.0
# 3038   Proprietorship  Computers;Mobile & related Accessories  110083.0
# 3615   Proprietorship         Apparels;Clothing & Accessories  311404.0
# 3325   Proprietorship                                     NaN  474001.0
#
#              city      state       revenuerange    age_of_business  \
# 3827  Sabarkantha    GUJARAT      1 - 10 Crores  More than 5 Years
# 1156          PUN     PUNJAB      1 - 10 Crores  More than 5 Years
# 3038   WEST DELHI      DELHI  60 Lacs - 1 Crore  More than 5 Years
# 3615     Bhilwara  RAJASTHAN       12 - 30 Lacs  More than 5 Years
# 3325          NaN        NaN       12 - 30 Lacs  More than 5 Years
#
#      delivery_method application_type product_type  desired_amount  \
# 3827         Pending              New    Term Loan         1500000
# 1156         Pending              New    Term Loan         1000000
# 3038         Pending              New    Term Loan               0
# 3615         Regular              New    Term Loan          150000
# 3325         Regular              New    Term Loan          100000
#
#      cibil_status                   Status                       Substatus  \
# 3827     REJECTED     Application Rejected                   Reject - Lead
# 1156     ACCEPTED  Application in Progress                     Not Started
# 3038     ACCEPTED     Application Rejected            Reject - By Customer
# 3615     ACCEPTED  Application in Progress  Application Details Incomplete
# 3325     ACCEPTED     Application Rejected                Reject - Expired
#
#                                        Rejection_reason terms_sent_date  \
# 3827  CIBIL overdue in past loan;CIBIL overdue in cu...             NaN
# 1156                                                NaN             NaN
# 3038              Client not responding/ not interested      2023-05-11
# 3615                                                NaN             NaN
# 3325                         Application Expired-Dedupe             NaN
#
#       terms_amount  interest_rate interest_rate_type  terms_tenure  \
# 3827           NaN            NaN                NaN           NaN
# 1156           NaN            NaN                NaN           NaN
# 3038      427406.0           1.62  Declining Balance          36.0
# 3615           NaN            NaN                NaN           NaN
# 3325           NaN            NaN                NaN           NaN
#
#       processing_fess insurer_name  insurance_amount  loan_amount FI_Status  \
# 3827              NaN          NaN               NaN          NaN       NaN
# 1156              NaN          NaN               NaN          NaN       NaN
# 3038          12608.0          NaN               0.0     427406.0       NaN
# 3615              NaN          NaN               NaN          NaN       NaN
# 3325              NaN          NaN               NaN          NaN       NaN
#
#       FI_Substatus acceptance_status     acceptance_reason risk_status  \
# 3827           NaN               NaN                   NaN         NaN
# 1156           NaN               NaN                   NaN         NaN
# 3038           NaN  Terms Non-Moving  Application Rejected         NaN
# 3615           NaN               NaN                   NaN         NaN
# 3325           NaN               NaN                   NaN         NaN
#
#      agreement_generated_date agreement_sent_date      agreement_status  \
# 3827                      NaN                 NaN                   NaN
# 1156                      NaN                 NaN                   NaN
# 3038                      NaN                 NaN  Application Rejected
# 3615                      NaN                 NaN                   NaN
# 3325                      NaN                 NaN                   NaN
#
#      agreement_sent_by  courier_company_name disbursal_date  \
# 3827               NaN                   NaN            NaN
# 1156               NaN                   NaN            NaN
# 3038               NaN                   NaN            NaN
# 3615               NaN                   NaN            NaN
# 3325               NaN                   NaN            NaN
#
#       disbursed_interest_rate  disbursed_amount  disbursed_tenure  \
# 3827                      NaN               NaN               NaN
# 1156                      NaN               NaN               NaN
# 3038                      NaN               NaN               NaN
# 3615                      NaN               NaN               NaN
# 3325                      NaN               NaN               NaN
#
#      first_installment_date
# 3827                    NaN
# 1156                    NaN
# 3038                    NaN
# 3615                    NaN
# 3325                    NaN

# %%
df_lendingkart['Customer ID'] = df_lendingkart['leadid']
df_lendingkart['LAN'] = df_lendingkart['application_id']
df_lendingkart['Contact No.'] = df_lendingkart['mobile_number']
df_lendingkart['Lender Partner '] = 'Lending Kart'
df_lendingkart['Merchant Name '] = df_lendingkart['customer_name']
df_lendingkart['Business Name '] = df_lendingkart['company_name']
df_lendingkart['Region'] = ''
df_lendingkart['State'] = df_lendingkart['state']
df_lendingkart['City'] = df_lendingkart['city']
df_lendingkart['Final Lead Status'] = df_lendingkart['Status']
df_lendingkart['Lead Created Date'] = df_lendingkart['app_created_date']
df_lendingkart['Lead last Disposition '] = df_lendingkart['Substatus']
df_lendingkart['Last disposition Date'] = df_lendingkart['app_modified_date']
df_lendingkart['Pendency'] = df_lendingkart['acceptance_status']
df_lendingkart['Monthly turn over of merchant'] = df_lendingkart['revenuerange']
df_lendingkart['Loan Amount Requested'] = df_lendingkart['desired_amount']
df_lendingkart['Sanctioned Amount'] = df_lendingkart['terms_amount']
df_lendingkart['PF Charges'] = df_lendingkart['processing_fess']
df_lendingkart['Doc Charges'] = ''
df_lendingkart['Insurance Charges'] = df_lendingkart['insurance_amount']
df_lendingkart['Net Disbursed Amount'] = df_lendingkart['disbursed_amount']
df_lendingkart['Interest Rate'] = df_lendingkart['interest_rate']
df_lendingkart['Interest Rate Type'] = df_lendingkart['interest_rate_type']
df_lendingkart['Tenure'] = df_lendingkart['terms_tenure']
df_lendingkart['Repayment Frequency'] = ''
df_lendingkart['Approved Date'] = df_lendingkart['terms_sent_date']
df_lendingkart['Disbursed Date'] = df_lendingkart['disbursal_date']
df_lendingkart['Post Sanctioned Status'] = df_lendingkart['acceptance_reason']
df_lendingkart['Rejected Reason'] = df_lendingkart['Rejection_reason']

# %%
df_lendingkart.columns
# Out:
# Index(['application_id', 'leadid', 'cls_app_id', 'email_id', 'mobile_number',
#        'created_by', 'SubDSA Details', 'customer_name', 'unique_id',
#        'app_created_date', 'app_modified_date', 'lead_source', 'created_by.1',
#        'company_name', 'regitration_type', 'industry', 'pincode', 'city',
#        'state', 'revenuerange', 'age_of_business', 'delivery_method',
#        'application_type', 'product_type', 'desired_amount', 'cibil_status',
#        'Status', 'Substatus', 'Rejection_reason', 'terms_sent_date',
#        'terms_amount', 'interest_rate', 'interest_rate_type', 'terms_tenure',
#        'processing_fess', 'insurer_name', 'insurance_amount', 'loan_amount',
#        'FI_Status', 'FI_Substatus', 'acceptance_status', 'acceptance_reason',
#        'risk_status', 'agreement_generated_date', 'agreement_sent_date',
#        'agreement_status', 'agreement_sent_by', 'courier_company_name',
#        'disbursal_date', 'disbursed_interest_rate', 'disbursed_amount',
#        'disbursed_tenure', 'first_installment_date', 'Customer ID', 'LAN',
#        'Contact No.', 'Lender Partner ', 'Merchant Name ', 'Business Name ',
#        'Region', 'State', 'City', 'Final Lead Status', 'Lead Created Date',
#        'Lead last Disposition ', 'Last disposition Date', 'Pendency',
#        'Monthly turn over of merchant', 'Loan Amount Requested',
#        'Sanctioned Amount', 'PF Charges', 'Doc Charges', 'Insurance Charges',
#        'Net Disbursed Amount', 'Interest Rate', 'Interest Rate Type', 'Tenure',
#        'Repayment Frequency', 'Approved Date', 'Disbursed Date',
#        'Post Sanctioned Status', 'Rejected Reason'],
#       dtype='object')

# %%
df_lendingkart.dtypes
# Out:
# application_id                    object
# leadid                             int64
# cls_app_id                        object
# email_id                          object
# mobile_number                    float64
# created_by                        object
# SubDSA Details                   float64
# customer_name                     object
# unique_id                         object
# app_created_date                  object
# app_modified_date                 object
# lead_source                       object
# created_by.1                      object
# company_name                      object
# regitration_type                  object
# industry                          object
# pincode                          float64
# city                              object
# state                             object
# revenuerange                      object
# age_of_business                   object
# delivery_method                   object
# application_type                  object
# product_type                      object
# desired_amount                     int64
# cibil_status                      object
# Status                            object
# Substatus                         object
# Rejection_reason                  object
# terms_sent_date                   object
# terms_amount                     float64
# interest_rate                    float64
# interest_rate_type                object
# terms_tenure                     float64
# processing_fess                  float64
# insurer_name                      object
# insurance_amount                 float64
# loan_amount                      float64
# FI_Status                         object
# FI_Substatus                     float64
# acceptance_status                 object
# acceptance_reason                 object
# risk_status                       object
# agreement_generated_date          object
# agreement_sent_date               object
# agreement_status                  object
# agreement_sent_by                 object
# courier_company_name             float64
# disbursal_date                    object
# disbursed_interest_rate          float64
# disbursed_amount                 float64
# disbursed_tenure                 float64
# first_installment_date            object
# Customer ID                        int64
# LAN                               object
# Contact No.                      float64
# Lender Partner                    object
# Merchant Name                     object
# Business Name                     object
# Region                            object
# State                             object
# City                              object
# Final Lead Status                 object
# Lead Created Date                 object
# Lead last Disposition             object
# Last disposition Date             object
# Pendency                          object
# Monthly turn over of merchant     object
# Loan Amount Requested              int64
# Sanctioned Amount                float64
# PF Charges                       float64
# Doc Charges                       object
# Insurance Charges                float64
# Net Disbursed Amount             float64
# Interest Rate                    float64
# Interest Rate Type                object
# Tenure                           float64
# Repayment Frequency               object
# Approved Date                     object
# Disbursed Date                    object
# Post Sanctioned Status            object
# Rejected Reason                   object
# dtype: object

# %%
df_flexiloansA = pd.read_excel(path+'\\FL\\FL.xlsx',sheet_name='approved',engine='openpyxl')

# %%
df_flexiloansA['Customer ID'] = df_flexiloansA['code']
df_flexiloansA['LAN'] = df_flexiloansA['number']
df_flexiloansA['Contact No.'] = df_flexiloansA['Mobile_no']
df_flexiloansA['Lender Partner '] = 'Flexi Loan'
df_flexiloansA['Merchant Name '] = ''
df_flexiloansA['Business Name '] = df_flexiloansA['business_name']
df_flexiloansA['Region'] = ''
df_flexiloansA['State'] = ''
df_flexiloansA['City'] = ''
df_flexiloansA['Final Lead Status'] = df_flexiloansA['s1']
df_flexiloansA['Lead Created Date'] = df_flexiloansA['Created']
df_flexiloansA['Lead last Disposition '] = df_flexiloansA['s3']
df_flexiloansA['Last disposition Date'] = ''
df_flexiloansA['Pendency'] = ''
df_flexiloansA['Monthly turn over of merchant'] = ''
df_flexiloansA['Loan Amount Requested'] = df_flexiloansA['Loan Amount']
df_flexiloansA['Sanctioned Amount'] = df_flexiloansA['Sanctioned Amount']
df_flexiloansA['PF Charges'] = df_flexiloansA['Pf Charges']
df_flexiloansA['Doc Charges'] = df_flexiloansA['Doc Charges']
df_flexiloansA['Insurance Charges'] = ''
df_flexiloansA['Net Disbursed Amount'] = df_flexiloansA['Net Disbursed Amount']
df_flexiloansA['Interest Rate'] = df_flexiloansA['Interest Rate']
df_flexiloansA['Interest Rate Type'] = df_flexiloansA['Interest Rate Type']
df_flexiloansA['Tenure'] = df_flexiloansA['Tenure']
df_flexiloansA['Repayment Frequency'] = df_flexiloansA['Repayment Frequency']
df_flexiloansA['Approved Date'] = df_flexiloansA['Approved Date']
df_flexiloansA['Disbursed Date'] = df_flexiloansA['Disbursed Date']
df_flexiloansA['Post Sanctioned Status'] = ''
df_flexiloansA['Rejected Reason'] = ''

# %%
df_flexiloansI = pd.read_excel(path+'\\FL\\FL.xlsx',sheet_name='In_progress',engine='openpyxl')

# %%
df_flexiloansI.head()
# Out:
#             code                               business_name  \
# 0  65b9fec1axwci                                 MOBILE MALL
# 1  65bcda77g3gg8                                SAHIL MOBILE
# 2  65bdef81ys6zg                            DANISH & COMPANY
# 3  65c0f534sz8c1  KRISHNA MOBILE ACCESSORIES AND ELECTRONICS
# 4  65c1cad72a172                              JYOTI PHARMACY
#
#               application_no partner_application_number      lead_code  \
# 0  PEF-TAMAD-000-JAN24-00050   65b8fede8970297ad1f76b15  64d11f11ky5yu
# 1  PEF-PUCHI-000-FEB24-00003                        NaN  648168a943p3b
# 2  PNF-UTBIR-000-FEB24-00008                        NaN  65bdef818ubyn
# 3  PEF-MABAG-000-FEB24-00018   65c0efbb5cdb1822b782751d  65aca6164aubq
# 4  DEF-RAR.H-000-FEB24-00002                        NaN  64a647b12sd8q
#
#      Created       Hot Lead Date        Post_PD_date  Days Since Lead Created  \
# 0 2024-01-31 2024-02-05 13:16:36 2024-02-06 17:45:17                        0
# 1 2024-02-02 2024-02-07 18:32:33                 NaT                        0
# 2 2024-02-03 2024-02-06 16:13:18                 NaT                        0
# 3 2024-02-05 2024-02-07 11:36:30                 NaT                        0
# 4 2024-02-06 2024-02-06 11:58:08 2024-02-06 16:38:44                        0
#
#    Loan Amount  Total Calls Made  Calls Not Answered Fresh_Top_Up  \
# 0       500000                25                   6        Fresh
# 1      1000000                12                  10        Fresh
# 2      2500000                25                  22        Fresh
# 3      2000000                 4                   2        Fresh
# 4       600000                 4                   0        Fresh
#
#             s1        s2                        s3  \
# 0  In Progress  Hot Lead              Post PD Hold
# 1  In Progress  Hot Lead          Analysis Pending
# 2  In Progress  Hot Lead  POST PD Document Pending
# 3  In Progress  Hot Lead                        PD
# 4  In Progress  Hot Lead              Post PD Hold
#
#                                    Pending Documents  Pending Document Count  \
# 0  We found the following issue(s) with the banki...                       3
# 1  We found the following issue(s) with the banki...                       3
# 2  \nAdditional documents\nDocuments for 'Bank st...                       8
# 3  Documents for 'KYC'\nOptional, any 1:\nPAN Car...                       3
# 4  We found the following issue(s) with the banki...                       3
#
#    Priority                                      Document_Link       name  \
# 0         1  http://apply.flexiloans.com/?al=true&lm=64d11f...  Pine Labs
# 1         1  http://apply.flexiloans.com/?al=true&lm=648168...  Pine Labs
# 2         1  http://apply.flexiloans.com/?al=true&lm=65bdef...  Pine Labs
# 3         1  http://apply.flexiloans.com/?al=true&lm=65aca6...  Pine Labs
# 4         1  http://apply.flexiloans.com/?al=true&lm=64a647...  Pine Labs
#
#         platform        MTO  serviceable   Mobile_no             inserted_on
# 0            Web  1000000.0            1  9655222238 2024-02-08 03:30:13.418
# 1  Manual Upload  1500000.0            1  9988819995 2024-02-08 03:30:13.418
# 2            Web  1000000.0            0  7905107714 2024-02-08 03:30:13.418
# 3            Web  1000000.0            0  8085665629 2024-02-08 03:30:13.418
# 4    Bulk upload   500000.0            1  9728321132 2024-02-08 03:30:13.418

# %%
df_flexiloansI['Customer ID'] = df_flexiloansI['code']
df_flexiloansI['LAN'] = df_flexiloansI['application_no']
df_flexiloansI['Contact No.'] = df_flexiloansI['Mobile_no']
df_flexiloansI['Lender Partner '] = 'Flexi Loan'
df_flexiloansI['Merchant Name '] = ''
df_flexiloansI['Business Name '] = df_flexiloansI['business_name']
df_flexiloansI['Region'] = ''
df_flexiloansI['State'] = ''
df_flexiloansI['City'] = ''
df_flexiloansI['Final Lead Status'] = df_flexiloansI['s2']
df_flexiloansI['Lead Created Date'] = df_flexiloansI['Created']
df_flexiloansI['Lead last Disposition '] = df_flexiloansI['s3']
df_flexiloansI['Last disposition Date'] = ''
df_flexiloansI['Pendency'] = df_flexiloansI['Pending Documents']
df_flexiloansI['Monthly turn over of merchant'] = ''
df_flexiloansI['Loan Amount Requested'] = df_flexiloansI['Loan Amount']
df_flexiloansI['Sanctioned Amount'] = ''
df_flexiloansI['PF Charges'] = ''
df_flexiloansI['Doc Charges'] = ''
df_flexiloansI['Insurance Charges'] = ''
df_flexiloansI['Net Disbursed Amount'] = ''
df_flexiloansI['Interest Rate'] = ''
df_flexiloansI['Interest Rate Type'] = ''
df_flexiloansI['Tenure'] = ''
df_flexiloansI['Repayment Frequency'] = ''
df_flexiloansI['Approved Date'] = ''
df_flexiloansI['Disbursed Date'] = ''
df_flexiloansI['Post Sanctioned Status'] = ''
df_flexiloansI['Rejected Reason'] = ''

# %%
df_flexiloansR = pd.read_excel(path+'\\FL\\FL.xlsx',sheet_name='Rejected',engine='openpyxl')

# %%
df_flexiloansR.head()
# Out:
#             code                      business_name  \
# 0  65c448470t0vy                                NaN
# 1  65c4480f2wb02                     SMS SUPER MART
# 2  65c422e78b00r                 L.MARK ENTERPRISES
# 3  65c422c53rcwm                 L.MARK ENTERPRISES
# 4  65c38cc92b0i5  INCLUSION ACADEMY PRIVATE LIMITED
#
#               application_no partner_application_number      lead_code  \
# 0  PEF-KABEN-000-FEB24-00376                        NaN  65c4480f3puve
# 1  PNF-KABEN-000-FEB24-00614   65c4456c32406deb8246dc84  65c4480f3puve
# 2  PEF-TAVIC-000-FEB24-00002                        NaN  5e04b98fm9rgz
# 3  PEF-TAMAN-000-FEB24-00010   65c41f52b51af8acd97ffb1d  5e04b98fm9rgz
# 4  PNF-DEJAG-000-FEB24-00014   65c38b13c30ec1bd8443f44a  65c38cc9xk5cs
#
#   Post_PD_date    Created Hot Lead Date  Loan Amount  Total Calls Made  \
# 0          NaT 2024-02-08           NaT        50000               NaN
# 1          NaT 2024-02-08           NaT      1000000               NaN
# 2          NaT 2024-02-08           NaT        50000               NaN
# 3          NaT 2024-02-08           NaT       750000               NaN
# 4          NaT 2024-02-07           NaT      1000000               1.0
#
#    Calls Not Answered  Disbursed Date Approved Date Fresh_Top_Up  \
# 0                 NaN             NaN           NaT        Fresh
# 1                 NaN             NaN           NaT        Fresh
# 2                 NaN             NaN           NaT        Fresh
# 3                 NaN             NaN           NaT        Fresh
# 4                 0.0             NaN           NaT        Fresh
#
#              s1                s2                                   s3  \
# 0  Not approved  Lender Rejection                        Credit Policy
# 1  Not approved  Lender Rejection                        Credit Policy
# 2  Not approved  Lender Rejection                        Credit Policy
# 3  Not approved  Lender Rejection                        Credit Policy
# 4  Not approved  Seller Rejection  Required Documentation not Provided
#
#         Rejection_Reason       name       Rejected_Date platform        MTO  \
# 0  ["cre_reject_status"]  Pine Labs 2024-02-08 08:49:45      Web        NaN
# 1  ["cre_reject_status"]  Pine Labs 2024-02-08 08:48:49      Web  1000000.0
# 2  ["cre_reject_status"]  Pine Labs 2024-02-08 06:10:21      Web        NaN
# 3  ["cre_reject_status"]  Pine Labs 2024-02-08 06:09:42      Web  1000000.0
# 4  ["Document Required"]  Pine Labs 2024-02-07 19:57:38      Web  1000000.0
#
#    serviceable   Mobile_no             inserted_on
# 0            0  9972560285 2024-02-08 03:30:13.418
# 1            0  9972560285 2024-02-08 03:30:13.418
# 2            0  8220360839 2024-02-08 03:30:13.418
# 3            0  8220360839 2024-02-08 03:30:13.418
# 4            1  8287781952 2024-02-08 03:30:13.418

# %%
df_flexiloansR['Customer ID'] = df_flexiloansR['code']
df_flexiloansR['LAN'] = df_flexiloansR['application_no']
df_flexiloansR['Contact No.'] = df_flexiloansR['Mobile_no']
df_flexiloansR['Lender Partner '] = 'Flexi Loan'
df_flexiloansR['Merchant Name '] = ''
df_flexiloansR['Business Name '] = df_flexiloansR['business_name']
df_flexiloansR['Region'] = ''
df_flexiloansR['State'] = ''
df_flexiloansR['City'] = ''
df_flexiloansR['Final Lead Status'] = df_flexiloansR['s1']
df_flexiloansR['Lead Created Date'] = df_flexiloansR['Created']
df_flexiloansR['Lead last Disposition '] = df_flexiloansR['s3']
df_flexiloansR['Last disposition Date'] = ''
df_flexiloansR['Pendency'] = ''
df_flexiloansR['Monthly turn over of merchant'] = ''
df_flexiloansR['Loan Amount Requested'] = df_flexiloansR['Loan Amount']
df_flexiloansR['Sanctioned Amount'] = ''
df_flexiloansR['PF Charges'] = ''
df_flexiloansR['Doc Charges'] = ''
df_flexiloansR['Insurance Charges'] = ''
df_flexiloansR['Net Disbursed Amount'] = ''
df_flexiloansR['Interest Rate'] = ''
df_flexiloansR['Interest Rate Type'] = ''
df_flexiloansR['Tenure'] = ''
df_flexiloansR['Repayment Frequency'] = ''
df_flexiloansR['Approved Date'] = df_flexiloansR['Approved Date']
df_flexiloansR['Disbursed Date'] = ''
df_flexiloansR['Post Sanctioned Status'] = ''
df_flexiloansR['Rejected Reason'] = np.where(df_flexiloansR['s1']=='Not approved',df_flexiloansR['s2']+" & " + df_flexiloansR['s3'],"")

# %%
df_LK_final = df_lendingkart[['Customer ID', 'LAN',
       'Contact No.', 'Lender Partner ', 'Merchant Name ', 'Business Name ',
       'Region', 'State', 'City', 'Final Lead Status', 'Lead Created Date',
       'Lead last Disposition ', 'Last disposition Date', 'Pendency',
       'Monthly turn over of merchant', 'Loan Amount Requested',
       'Sanctioned Amount', 'PF Charges', 'Doc Charges', 'Insurance Charges',
       'Net Disbursed Amount', 'Interest Rate', 'Interest Rate Type', 'Tenure',
       'Repayment Frequency', 'Approved Date', 'Disbursed Date',
       'Post Sanctioned Status', 'Rejected Reason']]

# %%
df_FLA = df_flexiloansA[['Customer ID', 'LAN',
       'Contact No.', 'Lender Partner ', 'Merchant Name ', 'Business Name ',
       'Region', 'State', 'City', 'Final Lead Status', 'Lead Created Date',
       'Lead last Disposition ', 'Last disposition Date', 'Pendency',
       'Monthly turn over of merchant', 'Loan Amount Requested',
       'Sanctioned Amount', 'PF Charges', 'Doc Charges', 'Insurance Charges',
       'Net Disbursed Amount', 'Interest Rate', 'Interest Rate Type', 'Tenure',
       'Repayment Frequency', 'Approved Date', 'Disbursed Date',
       'Post Sanctioned Status', 'Rejected Reason']]

# %%
df_FLR = df_flexiloansR[['Customer ID', 'LAN',
       'Contact No.', 'Lender Partner ', 'Merchant Name ', 'Business Name ',
       'Region', 'State', 'City', 'Final Lead Status', 'Lead Created Date',
       'Lead last Disposition ', 'Last disposition Date', 'Pendency',
       'Monthly turn over of merchant', 'Loan Amount Requested',
       'Sanctioned Amount', 'PF Charges', 'Doc Charges', 'Insurance Charges',
       'Net Disbursed Amount', 'Interest Rate', 'Interest Rate Type', 'Tenure',
       'Repayment Frequency', 'Approved Date', 'Disbursed Date',
       'Post Sanctioned Status', 'Rejected Reason']]

# %%
df_FLI = df_flexiloansI[['Customer ID', 'LAN',
       'Contact No.', 'Lender Partner ', 'Merchant Name ', 'Business Name ',
       'Region', 'State', 'City', 'Final Lead Status', 'Lead Created Date',
       'Lead last Disposition ', 'Last disposition Date', 'Pendency',
       'Monthly turn over of merchant', 'Loan Amount Requested',
       'Sanctioned Amount', 'PF Charges', 'Doc Charges', 'Insurance Charges',
       'Net Disbursed Amount', 'Interest Rate', 'Interest Rate Type', 'Tenure',
       'Repayment Frequency', 'Approved Date', 'Disbursed Date',
       'Post Sanctioned Status', 'Rejected Reason']]

# %%
df_FL_final = df_FLA.append(df_FLR).append(df_FLI)

# %%
df_FL_final.head()
# Out:
#      Customer ID                        LAN  Contact No. Lender Partner   \
# 0  65aa5abbq6qe1  PNF-PUFEN-000-JAN24-00013   9023315800      Flexi Loan
# 1  6586daf61z5ki  PEF-MAKAL-000-DEC23-00047   8080807039      Flexi Loan
# 2  658544fbxchuh  PNF-MABAD-000-DEC23-00078   9763996082      Flexi Loan
# 3  6571c2a5itkqd  PEF-TALEV-000-DEC23-00001   9629508600      Flexi Loan
# 4  65ae638aj8kej  PEF-KABEN-000-JAN24-00698   8197837814      Flexi Loan
#
#   Merchant Name             Business Name  Region State City  \
# 0                 ARMAAN SALES CORPORATION
# 1                 Vighnesh Trading Company
# 2                               vin system
# 3                              JAI TRADERS
# 4                          T S ENTERPRISES
#
#   Final Lead Status Lead Created Date Lead last Disposition   \
# 0         Disbursed        2024-01-19                   None
# 1         Disbursed        2023-12-23                   None
# 2         Disbursed        2023-12-22                   None
# 3         Disbursed        2023-12-07                   None
# 4         Disbursed        2024-01-22                   None
#
#   Last disposition Date Pendency Monthly turn over of merchant  \
# 0
# 1
# 2
# 3
# 4
#
#    Loan Amount Requested Sanctioned Amount PF Charges Doc Charges  \
# 0                2000000           1500000       2.36        8850
# 1                1500000           1000000       2.36       11800
# 2                1500000            480000    14160.0           0
# 3                1500000            815000    28851.0           0
# 4                1500000            425000       3.54        5900
#
#   Insurance Charges Net Disbursed Amount Interest Rate Interest Rate Type  \
# 0                              1414362.0          21.2           Variable
# 1                               961209.0           1.2               Flat
# 2                               480000.0        2.1667               Flat
# 3                               815000.0          1.75               Flat
# 4                               392110.5           2.0               Flat
#
#   Tenure Repayment Frequency        Approved Date       Disbursed Date  \
# 0     36              Months  2024-01-20 20:47:22  2024-01-25 00:00:00
# 1     36              Months  2023-12-28 19:24:00  2023-12-30 00:00:00
# 2     36              Months  2024-01-02 18:21:47  2024-01-03 00:00:00
# 3     36              Months  2023-12-15 00:28:42  2023-12-17 00:00:00
# 4     24              Months  2024-01-29 12:28:40  2024-01-29 00:00:00
#
#   Post Sanctioned Status Rejected Reason
# 0
# 1
# 2
# 3
# 4

# %%
df_FL_final['Contact No.'].nunique()
# Out:
# 964

# %%
df_FL_final.shape
# Out:
# (1166, 29)

# %%
df_FL_final['Lead Created Date']=df_FL_final['Lead Created Date'].astype('datetime64[ns]')

# %%
df_FL_final['Lead Created Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df_LK_final['Lead Created Date']=df_LK_final['Lead Created Date'].astype('datetime64[ns]')

# %%
df_LK_final['Approved Date']=df_LK_final['Approved Date'].astype('datetime64[ns]')

# %%
df_FL_final['Sanctioned Amount'].dtype
# Out:
# dtype('O')

# %%
df_LK_final['Lead Created Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df_LK_final['Approved Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
#pd.to_numeric(df_FL_final['Sanctioned Amount'], errors="ignore")
df_FL_final['Sanctioned Amount']=df_FL_final['Sanctioned Amount'].replace('',0).astype(float)
df_FL_final['Sanctioned Amount'].dtype
# Out:
# dtype('float64')

# %%
#df_FL_final = df_FL_final.sort_values(by=['Contact No.','Lead Created Date'],ascending=[False,False])

# %%
df_LK_final['Disbursed Date'].dtype
df_LK_final['Disbursed Date']=pd.to_datetime(df_LK_final['Disbursed Date'])
df_LK_final['Disbursed Date'].dtype
df_FL_final['Disbursed Date'].dtype
df_FL_final['Disbursed Date']=pd.to_datetime(df_FL_final['Disbursed Date'])
df_FL_final['Disbursed Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df_LK_final['Sanctioned Amount'].dtype
# Out:
# dtype('float64')

# %%
#df_LK_final = df_LK_final.sort_values(by=['Contact No.','Lead Created Date'],ascending=[False,False])

# %%
df_FL_final = df_FL_final.sort_values(by=['Contact No.','Lead Created Date'],ascending=[False,False])

# %%
df_LK_final = df_LK_final.sort_values(by=['Contact No.','Lead Created Date'],ascending=[False,False])

# %%
T = str(((date.today()).strftime("%Y%m%d")))

# %%
df_Final = df_FL_final.append(df_LK_final)

# %%
#df_Final['Lead Created Date'] =pd.todatetime(df_Final['Lead Created Date'],format="%Y:%M:%D")

# %%
#df_Final = df_Final.sort_values(by=['Contact No.','Lead Created Date'],ascending=[True,True])

# %%
#adding dicsionary to add one column (Reverse Mapping)
Mapping_dictionary ={'Agreement Signed' : 'Approved' , 'Agreement Stage' : 'Approved' , 'Application in Progress' : 'InComplete Appl' ,'Application Rejected': 'Reject', 'Application under Evaluation' : 'In Process' , 'Approved' : 'Approved' , 
'Closed': 'Reject' , 'Disbursed': 'Disbursed' , 'Fresh Lead': 'New Lead', 'Hot Lead': 'In Process',
 'Not approved':'Reject' ,'Qualified Lead': 'InComplete Appl' ,'Terms & Conditions Stage' : 'Approved'}

#df_Final['Final Status'] = df_Final['Final Lead Status'].map(Mapping_dictionary)

df_Final['Final Status'] = np.where(df_Final['Lead last Disposition ']== "Not Started", 'New Lead',df_Final['Final Lead Status'].map(Mapping_dictionary))
#df_Final['Sanctioned Amount']=df_Final['Sanctioned Amount'].astype(int)
df_Final['Approved Amount']=df_Final['Sanctioned Amount'].div(100000).round(3)

# %%
#df_Final['Count']=df_Final.groupby(['Contact No.','Lender Partner '])[['Contact No.']].count()

# %%
df_Final.head()
# Out:
#        Customer ID                        LAN   Contact No. Lender Partner   \
# 39   65bcd780julvd  PEF-DEHAS-000-FEB24-00006  9.999401e+09      Flexi Loan
# 718  6595a84dddwdl  PEF-UTSHI-000-JAN24-00005  9.999361e+09      Flexi Loan
# 719  6595a828smnny  PEF-UTSHI-000-JAN24-00004  9.999361e+09      Flexi Loan
# 81   65bdf53aydgnq  PNF-HAANA-000-FEB24-00004  9.999204e+09      Flexi Loan
# 107  65ba17aca0ztu                        NaN  9.999165e+09      Flexi Loan
#
#     Merchant Name                  Business Name  Region State City  \
# 39                            Primex Laboratories
# 718                         SABHERWAL ELECTRICALS
# 719                         SABHERWAL ELECTRONICS
# 81                  MOHD NASEEM AHMED BOOK BINDER
# 107                                     TD EXPORT
#
#     Final Lead Status Lead Created Date         Lead last Disposition   \
# 39           Approved        2024-02-02                           None
# 718      Not approved        2024-01-04                  Credit Policy
# 719      Not approved        2024-01-04                  Credit Policy
# 81       Not approved        2024-02-03                 Not Interested
# 107            Closed        2024-01-31  Lender Reject in last 90 days
#
#     Last disposition Date Pendency Monthly turn over of merchant  \
# 39
# 718
# 719
# 81
# 107
#
#      Loan Amount Requested  Sanctioned Amount PF Charges Doc Charges  \
# 39                  400000           500000.0       2.95        5900
# 718                  50000                0.0
# 719                 925000                0.0
# 81                   50000                0.0
# 107                  50000                0.0
#
#     Insurance Charges Net Disbursed Amount Interest Rate Interest Rate Type  \
# 39                                466028.0           1.5               Flat
# 718
# 719
# 81
# 107
#
#     Tenure Repayment Frequency        Approved Date Disbursed Date  \
# 39      30              Months  2024-02-07 13:22:27            NaT
# 718                                             NaT            NaT
# 719                                             NaT            NaT
# 81                                              NaT            NaT
# 107                                             NaT            NaT
#
#     Post Sanctioned Status                    Rejected Reason Final Status  \
# 39                                                                Approved
# 718                          Lender Rejection & Credit Policy       Reject
# 719                          Lender Rejection & Credit Policy       Reject
# 81                          Seller Rejection & Not Interested       Reject
# 107                                                                 Reject
#
#      Approved Amount
# 39               5.0
# 718              0.0
# 719              0.0
# 81               0.0
# 107              0.0

# %%
df_Final.dtypes
# Out:
# Customer ID                              object
# LAN                                      object
# Contact No.                             float64
# Lender Partner                           object
# Merchant Name                            object
# Business Name                            object
# Region                                   object
# State                                    object
# City                                     object
# Final Lead Status                        object
# Lead Created Date                datetime64[ns]
# Lead last Disposition                    object
# Last disposition Date                    object
# Pendency                                 object
# Monthly turn over of merchant            object
# Loan Amount Requested                     int64
# Sanctioned Amount                       float64
# PF Charges                               object
# Doc Charges                              object
# Insurance Charges                        object
# Net Disbursed Amount                     object
# Interest Rate                            object
# Interest Rate Type                       object
# Tenure                                   object
# Repayment Frequency                      object
# Approved Date                            object
# Disbursed Date                   datetime64[ns]
# Post Sanctioned Status                   object
# Rejected Reason                          object
# Final Status                             object
# Approved Amount                         float64
# dtype: object

# %%
df_Indifi= pd.read_csv(path+'\\Indifi\\applications.csv')

# %%
df_Indifi.head()
# Out:
#    request_id                                    id  \
# 0     7255662  1dfdb340-f774-4a93-a528-be7f4b46e108
# 1     7255019  fa862140-403f-42fa-af93-76f7b4b74665
# 2     7254919  ed0d2dc1-b3e8-4eb7-a429-2e4deac00ef1
# 3     7254593  5a51c8bc-9e2a-4698-97d8-7d25e8845c31
# 4     7254451  1b85f98e-1271-4c07-b4af-709737523fac
#
#                                          name         phone  \
# 0                               OPALO VENTURE  9.497046e+09
# 1                                APPLE GARAGE  8.408000e+09
# 2  VIJAY COMPUTERS(COMPUTER SALES & SERVICES)  9.822857e+09
# 3                           Red apple mobiles  9.686860e+09
# 4              K N S FURNITURE AND FURNISHING  9.886579e+09
#
#              anchor_unique_id    anchor        city     location  \
# 0                         NaN  Pinelabs         NaN          NaN
# 1  {65c388ddc30ec1bd8443f42f}  Pinelabs     Panipat      Haryana
# 2                         NaN  Pinelabs  Aurangabad  Maharashtra
# 3                         NaN  Pinelabs         NaN          NaN
# 4                         NaN  Pinelabs         NaN          NaN
#
#    applied_amount       state   lead_date lead_time application_date  \
# 0       1000000.0    Rejected  07-02-2024     10:43       07-02-2024
# 1             NaN  Incomplete  07-02-2024     07:11       07-02-2024
# 2             0.0  Incomplete  07-02-2024     06:29       07-02-2024
# 3         50000.0  Incomplete  07-02-2024     05:50       07-02-2024
# 4       1500000.0    Rejected  07-02-2024     05:26       07-02-2024
#
#   application_time  sanction_amount sanction_date sanction_time  \
# 0            10:24              NaN           NaN           NaN
# 1            07:18              NaN           NaN           NaN
# 2            06:59              NaN           NaN           NaN
# 3            05:50              NaN           NaN           NaN
# 4            05:45              NaN           NaN           NaN
#
#    disbursed_amount disbursed_date disbursed_time  interest_rate  \
# 0               NaN            NaN            NaN            NaN
# 1               NaN            NaN            NaN            NaN
# 2               NaN            NaN            NaN            NaN
# 3               NaN            NaN            NaN            NaN
# 4               NaN            NaN            NaN            NaN
#
#    processing_fee rejection_date rejection_time        rejection_reason  \
# 0             NaN     07-02-2024          10:29  Credit Risk Assessment
# 1             NaN            NaN            NaN                     NaN
# 2             NaN            NaN            NaN                     NaN
# 3             NaN            NaN            NaN                     NaN
# 4             NaN     07-02-2024          05:46  Credit Risk Assessment
#
#   utm_source utm_campaign utm_medium  is_renewed business_nature  \
# 0       '---         '---       '---       False             NaN
# 1       '---         '---       '---       False         Trading
# 2       '---         '---       '---       False             NaN
# 3       '---         '---       '---       False             NaN
# 4       '---         '---       '---       False             NaN
#
#    anchor_applicationid application_completion_date  \
# 0                   NaN                         NaN
# 1                   NaN                         NaN
# 2                   NaN                         NaN
# 3                   NaN                         NaN
# 4                   NaN                         NaN
#
#   application_completion_time  is_womenled fast_loan_link rejection_code  \
# 0                         NaN          NaN             '-  credit_reject
# 1                         NaN          NaN             '-            NaN
# 2                         NaN          NaN             '-            NaN
# 3                         NaN          NaN             '-            NaN
# 4                         NaN          NaN             '-  credit_reject
#
#    dsa_agent_id
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
df_Indifi.columns
# Out:
# Index(['request_id', 'id', 'name', 'phone', 'anchor_unique_id', 'anchor',
#        'city', 'location', 'applied_amount', 'state', 'lead_date', 'lead_time',
#        'application_date', 'application_time', 'sanction_amount',
#        'sanction_date', 'sanction_time', 'disbursed_amount', 'disbursed_date',
#        'disbursed_time', 'interest_rate', 'processing_fee', 'rejection_date',
#        'rejection_time', 'rejection_reason', 'utm_source', 'utm_campaign',
#        'utm_medium', 'is_renewed', 'business_nature', 'anchor_applicationid',
#        'application_completion_date', 'application_completion_time',
#        'is_womenled', 'fast_loan_link', 'rejection_code', 'dsa_agent_id'],
#       dtype='object')

# %%
df_Indifi.dtypes
# Out:
# request_id                       int64
# id                              object
# name                            object
# phone                          float64
# anchor_unique_id                object
# anchor                          object
# city                            object
# location                        object
# applied_amount                 float64
# state                           object
# lead_date                       object
# lead_time                       object
# application_date                object
# application_time                object
# sanction_amount                float64
# sanction_date                   object
# sanction_time                   object
# disbursed_amount               float64
# disbursed_date                  object
# disbursed_time                  object
# interest_rate                  float64
# processing_fee                 float64
# rejection_date                  object
# rejection_time                  object
# rejection_reason                object
# utm_source                      object
# utm_campaign                    object
# utm_medium                      object
# is_renewed                        bool
# business_nature                 object
# anchor_applicationid           float64
# application_completion_date     object
# application_completion_time     object
# is_womenled                    float64
# fast_loan_link                  object
# rejection_code                  object
# dsa_agent_id                   float64
# dtype: object

# %%
df_Indifi[df_Indifi['disbursed_date'].notnull()].head(10)
# Out:
#      request_id                                    id  \
# 75      7196038  7a9fecf5-6db5-4155-8a49-697082d4790e
# 119     7176890  e1b05852-9b56-4093-8ae1-a03f3542e8ca
# 135     7170159  cd2e9399-b151-4429-ac68-f96d8f4e1ea9
# 140     7168231  2ee603eb-e204-49f9-86ab-52d62beb8c26
# 170     7155104  618dd7d6-e3ca-4bbb-878c-ca4ee371f022
# 173     7153896  6f3f5ef9-3623-4e48-87a5-9ccd7a5aa18f
# 245     7112759  e67cfc6b-e03a-45ae-a5a4-7cc2f82157a2
# 308     7075576  ccc22376-3e1c-4b57-9b8b-54ec9c869e6a
# 368     7055715  e04beb18-6fd7-46b0-9cb1-caffc536c967
# 373     7054307  57802980-8085-4086-befa-1b06cb443dc3
#
#                          name         phone               anchor_unique_id  \
# 75   KAMALNAYAN MOBILE SHOPEE  9.860117e+09                   {02496237,0}
# 119               U.K TELECOM  9.837687e+09                           {00}
# 135                  Mobicity  7.002828e+09                           {00}
# 140      PANKHOODI COLLECTION  9.829143e+09                           {00}
# 170       MILLENNIUM VENTURES  9.971400e+09                           {00}
# 173           BALA SUPER SHOP  7.358499e+09                           {00}
# 245        KGN MOBILE TELECOM  9.729553e+09  {00,65a79bf0dad955d682c70996}
# 308   CREATIVE POWER SOLUTION  9.943990e+09                           {00}
# 368            MY PLANET SHOP  9.007874e+09  {00,659e9d49ad5623e931c34ad9}
# 373  AR Mobiles & Electronics  6.369522e+09                           {00}
#
#        anchor               city     location  applied_amount        state  \
# 75   Pinelabs             NAGPUR  Maharashtra        350000.0  Loan Active
# 119  Pinelabs           Haridwar  Uttarakhand        145000.0  Loan Active
# 135  Pinelabs              Thane  Maharashtra       1200000.0  Loan Active
# 140  Pinelabs             Jaipur    Rajasthan        300000.0  Loan Active
# 170  Pinelabs          Faridabad      Haryana         99000.0  Loan Active
# 173  Pinelabs            Chennai   Tamil Nadu       2000000.0  Loan Active
# 245  Pinelabs          Faridabad      Haryana        373000.0  Loan Active
# 308  Pinelabs         Coimbatore   Tamil Nadu       1634000.0  Loan Active
# 368  Pinelabs  North 24 Parganas  West Bengal       1714000.0  Loan Active
# 373  Pinelabs        Pudukkottai   Tamil Nadu        198000.0  Loan Active
#
#       lead_date lead_time application_date application_time  sanction_amount  \
# 75   31-01-2024     08:16       31-01-2024            08:16         355411.0
# 119  27-01-2024     02:07       27-01-2024            02:20         147241.0
# 135  25-01-2024     06:37       25-01-2024            06:37        1218552.0
# 140  25-01-2024     12:24       25-01-2024            01:38         304638.0
# 170  23-01-2024     06:04       23-01-2024            06:53         100531.0
# 173  23-01-2024     03:55       23-01-2024            03:55        1000000.0
# 245  17-01-2024     02:51       17-01-2024            03:04         378767.0
# 308  12-01-2024     07:51       12-01-2024            07:27        1634000.0
# 368  10-01-2024     07:35       10-01-2024            07:35         588967.0
# 373  10-01-2024     05:11       10-01-2024            05:02         201061.0
#
#     sanction_date sanction_time  disbursed_amount disbursed_date  \
# 75     03-02-2024         12:07          355411.0     07-02-2024
# 119    31-01-2024         12:52          147241.0     31-01-2024
# 135    27-01-2024         06:44         1218552.0     29-01-2024
# 140    27-01-2024         06:17          304638.0     30-01-2024
# 170    27-01-2024         04:32          100531.0     30-01-2024
# 173    30-01-2024         05:11         1000000.0     03-02-2024
# 245    29-01-2024         04:07          378767.0     31-01-2024
# 308    20-01-2024         11:35         1634000.0     30-01-2024
# 368    15-01-2024         11:59          588967.0     17-01-2024
# 373    11-01-2024         02:30          201061.0     17-01-2024
#
#     disbursed_time  interest_rate  processing_fee rejection_date  \
# 75           07:14           32.0        16733.46            NaN
# 119          05:00           27.0         6949.78            NaN
# 135          07:17           27.0        35803.49            NaN
# 140          07:23           23.0        14342.97            NaN
# 170          05:24           35.0         4733.20            NaN
# 173          05:00           21.0        47200.00            NaN
# 245          06:41           24.0        13363.66            NaN
# 308          05:00           21.0        67291.39            NaN
# 368          02:57           21.0        20779.93            NaN
# 373          11:54           34.0         9466.35            NaN
#
#     rejection_time rejection_reason utm_source utm_campaign utm_medium  \
# 75             NaN              NaN       '---         '---       '---
# 119            NaN              NaN       '---         '---       '---
# 135            NaN              NaN       '---         '---       '---
# 140            NaN              NaN       '---         '---       '---
# 170            NaN              NaN       '---         '---       '---
# 173            NaN              NaN       '---         '---       '---
# 245            NaN              NaN       '---         '---       '---
# 308            NaN              NaN       '---         '---       '---
# 368            NaN              NaN       '---         '---       '---
# 373            NaN              NaN       '---         '---       '---
#
#      is_renewed business_nature  anchor_applicationid  \
# 75         True          Retail                   NaN
# 119       False          Retail                   NaN
# 135       False          Retail                   NaN
# 140       False          Retail                   NaN
# 170       False          Retail                   NaN
# 173       False          Retail                   NaN
# 245       False          Retail                   NaN
# 308       False         Trading                   NaN
# 368       False          Retail                   NaN
# 373       False          Retail                   NaN
#
#     application_completion_date application_completion_time  is_womenled  \
# 75                   02-02-2024                       04:24          NaN
# 119                  30-01-2024                       01:40          NaN
# 135                  25-01-2024                       07:45          NaN
# 140                  25-01-2024                       04:07          NaN
# 170                  25-01-2024                       05:59          NaN
# 173                  25-01-2024                       03:58          NaN
# 245                  18-01-2024                       12:07          NaN
# 308                  18-01-2024                       10:37          NaN
# 368                  11-01-2024                       02:02          NaN
# 373                  10-01-2024                       05:14          NaN
#
#     fast_loan_link rejection_code  dsa_agent_id
# 75              '-            NaN           NaN
# 119             '-            NaN           NaN
# 135             '-            NaN           NaN
# 140             '-            NaN           NaN
# 170             '-            NaN           NaN
# 173             '-            NaN           NaN
# 245             '-            NaN           NaN
# 308             '-            NaN           NaN
# 368             '-            NaN           NaN
# 373             '-            NaN           NaN

# %%
Mapping_dictionary_Indifi ={'Documentation Pending' : 'Approved' , 'Incomplete' : 'InComplete Appl' , 'Loan Active' : 'Disbursed' ,'Offer Acceptance Pending': 'Approved', 'Processing For Offer' : 'In Process' , 'Rejected' : 'Reject' , 
'Withdrawn': 'Reject','Ready To Disburse':'Approved','Under Review For Offer':'In Process'}

# %%
df_Indifi['Customer ID'] = df_Indifi['anchor_unique_id']
df_Indifi['LAN'] = df_Indifi['request_id']
df_Indifi['Contact No.'] = df_Indifi['phone']
df_Indifi['Lender Partner '] = 'INDIFI'
df_Indifi['Merchant Name '] = ''
df_Indifi['Business Name '] = df_Indifi['name']
df_Indifi['Region'] = ''
df_Indifi['State'] = df_Indifi['location']
df_Indifi['City'] = df_Indifi['city']
df_Indifi['Final Lead Status'] =df_Indifi['state']
df_Indifi['Lead Created Date'] = df_Indifi['lead_date']
df_Indifi['Lead last Disposition '] =df_Indifi['state']
df_Indifi['Last disposition Date'] =df_Indifi['application_completion_date']
df_Indifi['Pendency'] =''
df_Indifi['Monthly turn over of merchant'] = ''
df_Indifi['Loan Amount Requested'] = df_Indifi['applied_amount']
df_Indifi['Sanctioned Amount'] =df_Indifi['sanction_amount']
df_Indifi['PF Charges'] =''
df_Indifi['Doc Charges'] = ''
df_Indifi['Insurance Charges'] = ''
df_Indifi['Net Disbursed Amount'] =df_Indifi['disbursed_amount']
df_Indifi['Interest Rate'] = df_Indifi['interest_rate']
df_Indifi['Interest Rate Type'] = ''
df_Indifi['Tenure'] =''
df_Indifi['Repayment Frequency'] = ''
df_Indifi['Approved Date'] =df_Indifi['sanction_date']
df_Indifi['Disbursed Date'] =df_Indifi['disbursed_date']
df_Indifi['Post Sanctioned Status'] = ''
df_Indifi['Rejected Reason'] =df_Indifi['rejection_reason']
df_Indifi['Final Status']=df_Indifi['state'].map(Mapping_dictionary_Indifi)
df_Indifi['Sanctioned Amount'] = pd.to_numeric(df_Indifi['Sanctioned Amount'], errors='coerce')
df_Indifi['Approved Amount']=df_Indifi['Sanctioned Amount'].div(100000).round(3)
df_Indifi['lead_time']=df_Indifi['lead_time']

# %%
df_Indifi_final=df_Indifi[['Customer ID', 'LAN',
       'Contact No.', 'Lender Partner ', 'Merchant Name ', 'Business Name ',
       'Region', 'State', 'City', 'Final Lead Status', 'Lead Created Date',
       'Lead last Disposition ', 'Last disposition Date', 'Pendency',
       'Monthly turn over of merchant', 'Loan Amount Requested',
       'Sanctioned Amount', 'PF Charges', 'Doc Charges', 'Insurance Charges',
       'Net Disbursed Amount', 'Interest Rate', 'Interest Rate Type', 'Tenure',
       'Repayment Frequency', 'Approved Date', 'Disbursed Date',
       'Post Sanctioned Status', 'Rejected Reason','Final Status','Approved Amount','lead_time']]

# %%
df_Indifi_final.dtypes
# Out:
# Customer ID                       object
# LAN                                int64
# Contact No.                      float64
# Lender Partner                    object
# Merchant Name                     object
# Business Name                     object
# Region                            object
# State                             object
# City                              object
# Final Lead Status                 object
# Lead Created Date                 object
# Lead last Disposition             object
# Last disposition Date             object
# Pendency                          object
# Monthly turn over of merchant     object
# Loan Amount Requested            float64
# Sanctioned Amount                float64
# PF Charges                        object
# Doc Charges                       object
# Insurance Charges                 object
# Net Disbursed Amount             float64
# Interest Rate                    float64
# Interest Rate Type                object
# Tenure                            object
# Repayment Frequency               object
# Approved Date                     object
# Disbursed Date                    object
# Post Sanctioned Status            object
# Rejected Reason                   object
# Final Status                      object
# Approved Amount                  float64
# lead_time                         object
# dtype: object

# %%
#df_Indifi_final['Disbursed Date']=df_Indifi_final['Disbursed Date'].astype('datetime64[ns]')

# %%
df_Indifi_final['Disbursed Date'] = pd.to_datetime(df_Indifi_final['Disbursed Date'].str.slice(6,10)+'-'+df_Indifi_final['Disbursed Date'].str.slice(3,5)+'-'+df_Indifi_final['Disbursed Date'].str.slice(0,2))

# %%
df_Indifi_final['Disbursed Date']=pd.to_datetime(df_Indifi_final['Disbursed Date'], errors='coerce')

# %%
df_Indifi_final['Lead Created Date'] = pd.to_datetime(df_Indifi_final['Lead Created Date'].str.slice(6,10)+'-'+df_Indifi_final['Lead Created Date'].str.slice(3,5)+'-'+df_Indifi_final['Lead Created Date'].str.slice(0,2))

# %%
df_Indifi_final['Lead Created Date']=pd.to_datetime(df_Indifi_final['Lead Created Date'], errors='coerce')

# %%
df_Indifi_final['Approved Date'] = pd.to_datetime(df_Indifi_final['Approved Date'].str.slice(6,10)+'-'+df_Indifi_final['Approved Date'].str.slice(3,5)+'-'+df_Indifi_final['Approved Date'].str.slice(0,2))

# %%
df_Indifi_final['Approved Date']=pd.to_datetime(df_Indifi_final['Approved Date'], errors='coerce')

# %%
df_Indifi_final['Loan Amount Requested']=df_Indifi_final['Loan Amount Requested'].astype('Int64',errors='ignore')

# %%
df_Indifi_final['Net Disbursed Amount']=df_Indifi_final['Net Disbursed Amount'].astype(object)

# %%
df_Indifi_final['Interest Rate']=df_Indifi_final['Interest Rate'].astype(object)

# %%
df_Indifi_final.dtypes
# Out:
# Customer ID                              object
# LAN                                       int64
# Contact No.                             float64
# Lender Partner                           object
# Merchant Name                            object
# Business Name                            object
# Region                                   object
# State                                    object
# City                                     object
# Final Lead Status                        object
# Lead Created Date                datetime64[ns]
# Lead last Disposition                    object
# Last disposition Date                    object
# Pendency                                 object
# Monthly turn over of merchant            object
# Loan Amount Requested                     Int64
# Sanctioned Amount                       float64
# PF Charges                               object
# Doc Charges                              object
# Insurance Charges                        object
# Net Disbursed Amount                     object
# Interest Rate                            object
# Interest Rate Type                       object
# Tenure                                   object
# Repayment Frequency                      object
# Approved Date                    datetime64[ns]
# Disbursed Date                   datetime64[ns]
# Post Sanctioned Status                   object
# Rejected Reason                          object
# Final Status                             object
# Approved Amount                         float64
# lead_time                                object
# dtype: object

# %%
df_Indifi_final = df_Indifi_final.sort_values(by=['Contact No.','Lead Created Date','lead_time'],ascending=[False,False,False])

# %%
df_Final = df_Final.append(df_Indifi_final)

# %%
path = os.getcwd()

# %%
path
# Out:
# 'C:\\Users\\Tithi Hunka\\OneDrive - Pine Labs Private Limited\\TermLoans Code_Dummy'

# %%
df_Final.to_excel(path+'\\Output\\Consolidated(LK_FL_Indifi)'+ T+'.xlsx',index=False)

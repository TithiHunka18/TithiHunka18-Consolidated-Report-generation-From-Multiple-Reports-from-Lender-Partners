# %%
import pandas as pd
import numpy as np
import warnings
import time
from datetime import datetime, timedelta, date
warnings.filterwarnings('ignore')
import os
pd.options.display.max_columns = 500
pd.options.display.max_rows = 500
from dateutil.relativedelta import relativedelta
from numpy import concatenate as cct
import glob

# %%
import openpyxl

# %%
path = os.getcwd()

# %%
path
# Out:
# 'C:\\Users\\Tithi Hunka\\OneDrive - Pine Labs Private Limited\\TermLoans Code_Dummy'

# %%
df_lendingkart = pd.read_csv(path+'\\LK\\LK.csv')

# %%
df_lendingkart.head()
# Out:
#   application_id    leadid     cls_app_id                       email_id  \
# 0  LAI-120307029  33857735  LAI-120307029         gopaljaat061@gmail.com
# 1  LAI-121192478  35231225  LAI-121192478        paulpankaj942@gmail.com
# 2  LAI-119728260  32991438  LAI-119728260      sakirhussainkmk@gmail.com
# 3  LAI-121184893  35219818  LAI-121184893  hiteshsathavara9876@gmail.com
# 4  LAI-119811035  33121740  LAI-119811035      nasirkhan539279@gmail.com
#
#    mobile_number         created_by  SubDSA Details           customer_name  \
# 0   9.664212e+09    PineLabs_Direct             NaN             gopal singh
# 1   9.974912e+09    PineLabs_Direct             NaN             Pankaj Paul
# 2   9.947100e+09  Muthu Kumar Durai             NaN  SAKKIR HUSSAIN HUSSAIN
# 3   7.990231e+09    PineLabs_Direct             NaN    HITESHKUMAR SATHVARA
# 4   9.785539e+09    PineLabs_Direct             NaN             Nasir Nasir
#
#                   unique_id app_created_date app_modified_date  \
# 0                       NaN       28-10-2023        03-01-2024
# 1  65865d2e385b8f779af8505d       02-01-2024        03-01-2024
# 2                       NaN       16-09-2023        03-01-2024
# 3                       NaN       02-01-2024        03-01-2024
# 4                       NaN       23-09-2023        03-01-2024
#
#        lead_source       created_by.1  \
# 0  PineLabs_Direct    PineLabs_Direct
# 1  PineLabs_Direct    PineLabs_Direct
# 2  PineLabs_Direct  Muthu Kumar Durai
# 3  PineLabs_Direct    PineLabs_Direct
# 4  PineLabs_Direct    PineLabs_Direct
#
#                                         company_name regitration_type  \
# 0  SHRI KHATU SHYAM BOREWELL COM. AND MATERIAL SU...   Proprietorship
# 1                                                NaN   Proprietorship
# 2                                   KMKS PAINT HOUSE   Proprietorship
# 3                                                NaN   Proprietorship
# 4                                 RANSI POULTRY FARM   Proprietorship
#
#                                  industry   pincode        city      state  \
# 0  Food grains and other related products  321602.0   BHARATPUR  RAJASTHAN
# 1                Restaurant & Hospitality  392001.0         NaN        NaN
# 2         Industrial Supplies & Solutions  679322.0  MALAPPURAM     KERALA
# 3                                     NaN       NaN         NaN        NaN
# 4  Food grains and other related products  342601.0  BHOPALGARH  RAJASTHAN
#
#     revenuerange    age_of_business delivery_method application_type  \
# 0  1 - 10 Crores       1 to 5 Years         Pending              New
# 1   30 - 60 Lacs  More than 5 Years         Regular              New
# 2  1 - 10 Crores  More than 5 Years         Pending              New
# 3   30 - 60 Lacs       1 to 5 Years         Pending              New
# 4  1 - 10 Crores  More than 5 Years         Pending              New
#
#   product_type  desired_amount cibil_status                   Status  \
# 0    Term Loan               0     ACCEPTED     Application Rejected
# 1    Term Loan          700000        ERROR  Application in Progress
# 2    Term Loan               0     ACCEPTED     Application Rejected
# 3    Term Loan               0          NaN     Application Rejected
# 4    Term Loan               0     ACCEPTED     Application Rejected
#
#               Substatus            Rejection_reason terms_sent_date  \
# 0      Reject - Expired  Application Expired-Dedupe             NaN
# 1           Not Started                         NaN             NaN
# 2  Reject - By Customer       Client not responding      16-09-2023
# 3         Reject - Lead        Rejected by customer             NaN
# 4  Reject - By Customer       Client not responding      25-09-2023
#
#    terms_amount  interest_rate interest_rate_type  terms_tenure  \
# 0           NaN            NaN                NaN           NaN
# 1           NaN            NaN                NaN           NaN
# 2      692000.0           1.00               Flat          36.0
# 3           NaN            NaN                NaN           NaN
# 4      827000.0           1.81  Declining Balance          36.0
#
#    processing_fess           insurer_name  insurance_amount  loan_amount  \
# 0              NaN                    NaN               NaN          NaN
# 1              NaN                    NaN               NaN          NaN
# 2          33004.6  ICICI-Income Suraksha           27047.0     692000.0
# 3              NaN                    NaN               NaN          NaN
# 4          25397.0                    NaN               0.0     827000.0
#
#   FI_Status FI_Substatus acceptance_status     acceptance_reason  \
# 0       NaN          NaN               NaN                   NaN
# 1       NaN          NaN               NaN                   NaN
# 2       NaN          NaN  Terms Non-Moving  Application Rejected
# 3       NaN          NaN               NaN                   NaN
# 4       NaN          NaN  Terms Non-Moving  Application Rejected
#
#                  risk_status agreement_generated_date agreement_sent_date  \
# 0                        NaN                      NaN                 NaN
# 1                        NaN                      NaN                 NaN
# 2  Received for Verification                      NaN                 NaN
# 3                        NaN                      NaN                 NaN
# 4  Received for Verification                      NaN                 NaN
#
#        agreement_status agreement_sent_by  courier_company_name  \
# 0                   NaN               NaN                   NaN
# 1                   NaN               NaN                   NaN
# 2  Application Rejected               NaN                   NaN
# 3                   NaN               NaN                   NaN
# 4  Application Rejected               NaN                   NaN
#
#   disbursal_date  disbursed_interest_rate  disbursed_amount  disbursed_tenure  \
# 0            NaN                      NaN               NaN               NaN
# 1            NaN                      NaN               NaN               NaN
# 2            NaN                      NaN               NaN               NaN
# 3            NaN                      NaN               NaN               NaN
# 4            NaN                      NaN               NaN               NaN
#
#   first_installment_date
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN

# %%
df_lendingkart['app_created_date'] = df_lendingkart['app_created_date'].str.slice(6,10)+'-'+df_lendingkart['app_created_date'].str.slice(3,5)+'-'+df_lendingkart['app_created_date'].str.slice(0,2)

# %%
df_lendingkart['disbursal_date'] = df_lendingkart['disbursal_date'].str.slice(6,10)+'-'+df_lendingkart['disbursal_date'].str.slice(3,5)+'-'+df_lendingkart['disbursal_date'].str.slice(0,2)

# %%
df_lendingkart['terms_sent_date'] = df_lendingkart['terms_sent_date'].str.slice(6,10)+'-'+df_lendingkart['terms_sent_date'].str.slice(3,5)+'-'+df_lendingkart['terms_sent_date'].str.slice(0,2)

# %%
df_lendingkart['agreement_generated_date'] = df_lendingkart['agreement_generated_date'].str.slice(6,10)+'-'+df_lendingkart['agreement_generated_date'].str.slice(3,5)+'-'+df_lendingkart['agreement_generated_date'].str.slice(0,2)

# %%
df_lendingkart['app_created_date'].dtype
# Out:
# dtype('O')

# %%
df_lendingkart['disbursal_date'].dtype
# Out:
# dtype('O')

# %%
df_lendingkart.sample(5)
# Out:
#      application_id    leadid     cls_app_id                    email_id  \
# 3075  LAI-122275630  36825835  LAI-122275630  vinodh.kokila143@gmail.com
# 2417  LAI-121766458  36080571  LAI-121766458        nitingawand@yahoo.in
# 3319  LAI-120405795  33979654  LAI-120405795  sahilaroradixit5@gmail.com
# 686   LAI-121321738  35423380  LAI-121321738   noufalrahim1993@gmail.com
# 2277  LAI-116346417  27430351  LAI-116346417     gajendra00111@gmail.com
#
#       mobile_number       created_by  SubDSA Details   customer_name  \
# 3075   9.535485e+09  PineLabs_Direct             NaN     Vinodraj VP
# 2417   9.222196e+09  PineLabs_Direct             NaN    Nitin Gawand
# 3319   7.858966e+09  PineLabs_Direct             NaN     Sahil Dixit
# 686    9.744584e+09  PineLabs_Direct             NaN  NOUFAL RAHIM N
# 2277   8.010532e+09  PineLabs_Direct             NaN  Gajendra Singh
#
#                      unique_id app_created_date app_modified_date  \
# 3075  65fb2274842de95d36a34257       2024-03-20        20-03-2024
# 2417  65cb7152050d0fd39bebc492       2024-02-13        02-03-2024
# 3319  65445d3093ad1e8257ce48cb       2023-11-03        28-03-2024
# 686                        NaN       2024-01-10        17-01-2024
# 2277                       NaN       2023-01-23        28-02-2024
#
#           lead_source     created_by.1           company_name  \
# 3075  PineLabs_Direct  PineLabs_Direct                    NaN
# 2417  PineLabs_Direct  PineLabs_Direct  TANUSHREE MOBILE SHOP
# 3319  PineLabs_Direct  PineLabs_Direct                    NaN
# 686   PineLabs_Direct  PineLabs_Direct                    NaN
# 2277  PineLabs_Direct  PineLabs_Direct             GSB  INDIA
#
#      regitration_type                                industry   pincode  \
# 3075   Proprietorship                                     NaN  575003.0
# 2417   Proprietorship  Computers;Mobile & related Accessories  400083.0
# 3319   Proprietorship                                     NaN  803202.0
# 686    Proprietorship                                     NaN       NaN
# 2277   Proprietorship                Restaurant & Hospitality  560029.0
#
#            city        state   revenuerange    age_of_business  \
# 3075        NaN          NaN  1 - 10 Crores  More than 5 Years
# 2417     MUMBAI  MAHARASHTRA  1 - 10 Crores  More than 5 Years
# 3319        NaN          NaN   12 - 30 Lacs  More than 5 Years
# 686         NaN          NaN  1 - 10 Crores       1 to 5 Years
# 2277  BENGALURU    KARNATAKA  1 - 10 Crores       1 to 5 Years
#
#      delivery_method application_type product_type  desired_amount  \
# 3075         Regular              New    Term Loan           50000
# 2417         Regular              New    Term Loan         3000000
# 3319         Regular              New    Term Loan          100000
# 686          Pending              New    Term Loan               0
# 2277         Pending              New    Term Loan               0
#
#      cibil_status                   Status                       Substatus  \
# 3075     REJECTED     Application Rejected                   Reject - Lead
# 2417     ACCEPTED                Disbursed                       Disbursed
# 3319        ERROR     Application Rejected                Reject - Expired
# 686      ACCEPTED  Application in Progress  Application Details Incomplete
# 2277     ACCEPTED     Application Rejected                Reject - Expired
#
#                            Rejection_reason terms_sent_date  terms_amount  \
# 3075  CIBIL Rejected Due to Low CIBIL Score             NaN           NaN
# 2417                                    NaN      2024-02-28     2036000.0
# 3319             Application Expired-Dedupe             NaN           NaN
# 686                                     NaN             NaN           NaN
# 2277             Application Expired-Dedupe             NaN           NaN
#
#       interest_rate interest_rate_type  terms_tenure  processing_fess  \
# 3075            NaN                NaN           NaN              NaN
# 2417            0.9               Flat          36.0          78801.0
# 3319            NaN                NaN           NaN              NaN
# 686             NaN                NaN           NaN              NaN
# 2277            NaN                NaN           NaN              NaN
#
#                insurer_name  insurance_amount  loan_amount FI_Status  \
# 3075                    NaN               NaN          NaN       NaN
# 2417  ICICI-Income Suraksha           56092.0    2036000.0       NaN
# 3319                    NaN               NaN          NaN       NaN
# 686                     NaN               NaN          NaN       NaN
# 2277                    NaN               NaN          NaN       NaN
#
#      FI_Substatus acceptance_status acceptance_reason risk_status  \
# 3075          NaN               NaN               NaN         NaN
# 2417          NaN         Disbursed               NaN    Approved
# 3319          NaN               NaN               NaN         NaN
# 686           NaN               NaN               NaN         NaN
# 2277          NaN               NaN               NaN         NaN
#
#      agreement_generated_date agreement_sent_date agreement_status  \
# 3075                      NaN                 NaN              NaN
# 2417               2024-03-02          02-03-2024        Disbursed
# 3319                      NaN                 NaN              NaN
# 686                       NaN                 NaN              NaN
# 2277                      NaN                 NaN              NaN
#
#      agreement_sent_by  courier_company_name disbursal_date  \
# 3075               NaN                   NaN            NaN
# 2417             DocEx                   NaN     2024-03-02
# 3319               NaN                   NaN            NaN
# 686                NaN                   NaN            NaN
# 2277               NaN                   NaN            NaN
#
#       disbursed_interest_rate  disbursed_amount  disbursed_tenure  \
# 3075                      NaN               NaN               NaN
# 2417                     10.8         2036000.0              36.0
# 3319                      NaN               NaN               NaN
# 686                       NaN               NaN               NaN
# 2277                      NaN               NaN               NaN
#
#      first_installment_date
# 3075                    NaN
# 2417             03-04-2024
# 3319                    NaN
# 686                     NaN
# 2277                    NaN

# %%
df_lendingkart['Customer ID'] = df_lendingkart['leadid']
df_lendingkart['LAN'] = df_lendingkart['application_id']
df_lendingkart['Contact No.'] = df_lendingkart['mobile_number']
df_lendingkart['Lender Partner '] = 'Lending Kart'
df_lendingkart['Merchant Name '] = df_lendingkart['customer_name']
df_lendingkart['Business Name '] = df_lendingkart['company_name']
df_lendingkart['Region'] = ''
df_lendingkart['State'] = df_lendingkart['state']
df_lendingkart['City'] = df_lendingkart['city']
df_lendingkart['Final Lead Status'] = df_lendingkart['Status']
df_lendingkart['Lead Created Date'] = df_lendingkart['app_created_date']
df_lendingkart['Lead last Disposition '] = df_lendingkart['Substatus']
df_lendingkart['Last disposition Date'] = df_lendingkart['app_modified_date']
df_lendingkart['Pendency'] = df_lendingkart['acceptance_status']
df_lendingkart['Monthly turn over of merchant'] = df_lendingkart['revenuerange']
df_lendingkart['Loan Amount Requested'] = df_lendingkart['desired_amount']
df_lendingkart['Sanctioned Amount'] = df_lendingkart['terms_amount']
df_lendingkart['PF Charges'] = df_lendingkart['processing_fess']
df_lendingkart['Doc Charges'] = ''
df_lendingkart['Insurance Charges'] = df_lendingkart['insurance_amount']
df_lendingkart['Net Disbursed Amount'] = df_lendingkart['disbursed_amount']
df_lendingkart['Interest Rate'] = df_lendingkart['interest_rate']
df_lendingkart['Interest Rate Type'] = df_lendingkart['interest_rate_type']
df_lendingkart['Tenure'] = df_lendingkart['terms_tenure']
df_lendingkart['Repayment Frequency'] = ''
df_lendingkart['Offered Date'] = df_lendingkart['terms_sent_date']
df_lendingkart['Disbursed Date'] = df_lendingkart['disbursal_date']
df_lendingkart['Post Sanctioned Status'] = df_lendingkart['acceptance_reason']
df_lendingkart['Rejected Reason'] = df_lendingkart['Rejection_reason']
df_lendingkart['Offered Amount'] = df_lendingkart['terms_amount']
df_lendingkart['Sanction Date'] = df_lendingkart['agreement_generated_date']
df_lendingkart['Sanction Amount'] = np.where(~df_lendingkart['Sanction Date'].isnull(),df_lendingkart['terms_amount'],0)

# %%
df_lendingkart.columns
# Out:
# Index(['application_id', 'leadid', 'cls_app_id', 'email_id', 'mobile_number',
#        'created_by', 'SubDSA Details', 'customer_name', 'unique_id',
#        'app_created_date', 'app_modified_date', 'lead_source', 'created_by.1',
#        'company_name', 'regitration_type', 'industry', 'pincode', 'city',
#        'state', 'revenuerange', 'age_of_business', 'delivery_method',
#        'application_type', 'product_type', 'desired_amount', 'cibil_status',
#        'Status', 'Substatus', 'Rejection_reason', 'terms_sent_date',
#        'terms_amount', 'interest_rate', 'interest_rate_type', 'terms_tenure',
#        'processing_fess', 'insurer_name', 'insurance_amount', 'loan_amount',
#        'FI_Status', 'FI_Substatus', 'acceptance_status', 'acceptance_reason',
#        'risk_status', 'agreement_generated_date', 'agreement_sent_date',
#        'agreement_status', 'agreement_sent_by', 'courier_company_name',
#        'disbursal_date', 'disbursed_interest_rate', 'disbursed_amount',
#        'disbursed_tenure', 'first_installment_date', 'Customer ID', 'LAN',
#        'Contact No.', 'Lender Partner ', 'Merchant Name ', 'Business Name ',
#        'Region', 'State', 'City', 'Final Lead Status', 'Lead Created Date',
#        'Lead last Disposition ', 'Last disposition Date', 'Pendency',
#        'Monthly turn over of merchant', 'Loan Amount Requested',
#        'Sanctioned Amount', 'PF Charges', 'Doc Charges', 'Insurance Charges',
#        'Net Disbursed Amount', 'Interest Rate', 'Interest Rate Type', 'Tenure',
#        'Repayment Frequency', 'Offered Date', 'Disbursed Date',
#        'Post Sanctioned Status', 'Rejected Reason', 'Offered Amount',
#        'Sanction Date', 'Sanction Amount'],
#       dtype='object')

# %%
df_lendingkart.dtypes
# Out:
# application_id                    object
# leadid                             int64
# cls_app_id                        object
# email_id                          object
# mobile_number                    float64
# created_by                        object
# SubDSA Details                   float64
# customer_name                     object
# unique_id                         object
# app_created_date                  object
# app_modified_date                 object
# lead_source                       object
# created_by.1                      object
# company_name                      object
# regitration_type                  object
# industry                          object
# pincode                          float64
# city                              object
# state                             object
# revenuerange                      object
# age_of_business                   object
# delivery_method                   object
# application_type                  object
# product_type                      object
# desired_amount                     int64
# cibil_status                      object
# Status                            object
# Substatus                         object
# Rejection_reason                  object
# terms_sent_date                   object
# terms_amount                     float64
# interest_rate                    float64
# interest_rate_type                object
# terms_tenure                     float64
# processing_fess                  float64
# insurer_name                      object
# insurance_amount                 float64
# loan_amount                      float64
# FI_Status                         object
# FI_Substatus                      object
# acceptance_status                 object
# acceptance_reason                 object
# risk_status                       object
# agreement_generated_date          object
# agreement_sent_date               object
# agreement_status                  object
# agreement_sent_by                 object
# courier_company_name             float64
# disbursal_date                    object
# disbursed_interest_rate          float64
# disbursed_amount                 float64
# disbursed_tenure                 float64
# first_installment_date            object
# Customer ID                        int64
# LAN                               object
# Contact No.                      float64
# Lender Partner                    object
# Merchant Name                     object
# Business Name                     object
# Region                            object
# State                             object
# City                              object
# Final Lead Status                 object
# Lead Created Date                 object
# Lead last Disposition             object
# Last disposition Date             object
# Pendency                          object
# Monthly turn over of merchant     object
# Loan Amount Requested              int64
# Sanctioned Amount                float64
# PF Charges                       float64
# Doc Charges                       object
# Insurance Charges                float64
# Net Disbursed Amount             float64
# Interest Rate                    float64
# Interest Rate Type                object
# Tenure                           float64
# Repayment Frequency               object
# Offered Date                      object
# Disbursed Date                    object
# Post Sanctioned Status            object
# Rejected Reason                   object
# Offered Amount                   float64
# Sanction Date                     object
# Sanction Amount                  float64
# dtype: object

# %%
df_lendingkart['Sanction Amount'].replace('',0).astype(int)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 3431    0
# 3432    0
# 3433    0
# 3434    0
# 3435    0
# Name: Sanction Amount, Length: 3436, dtype: int32

# %%
df_flexiloansA = pd.read_excel(path+'\\FL\\FL.xlsx',sheet_name='approved',engine='openpyxl')

# %%
df_flexiloansA.columns
# Out:
# Index(['code', 'business_name', 'number', 'partner_application_number',
#        'lead_code', 'Post_PD_date', 'offered_amount_pd', 'Created',
#        'Hot Lead Date', 'Escrow Account Number', 'experiment_name',
#        'Loan Amount', 'Sanctioned Amount', 'Pf Charges', 'Doc Charges',
#        'Net Disbursed Amount', 'Interest Rate', 'Interest Rate Type', 'Tenure',
#        'Repayment Frequency', 'Disbursed Date', 'Approved Date',
#        'Post Sanctioned Status', 'Total Calls Made', 'Calls Not Answered',
#        'Fresh_Top_Up', 's1', 's2', 's3', 'Priority', 'name', 'platform', 'MTO',
#        'serviceable', 'Mobile_no', 'inserted_on'],
#       dtype='object')

# %%
df_flexiloansA['Customer ID'] = df_flexiloansA['code']
df_flexiloansA['LAN'] = df_flexiloansA['number']
df_flexiloansA['Contact No.'] = df_flexiloansA['Mobile_no']
df_flexiloansA['Lender Partner '] = 'Flexi Loan'
df_flexiloansA['Merchant Name '] = ''
df_flexiloansA['Business Name '] = df_flexiloansA['business_name']
df_flexiloansA['Region'] = ''
df_flexiloansA['State'] = ''
df_flexiloansA['City'] = ''
df_flexiloansA['Final Lead Status'] = df_flexiloansA['s1']
df_flexiloansA['Lead Created Date'] = df_flexiloansA['Created']
df_flexiloansA['Lead last Disposition '] = df_flexiloansA['s3']
df_flexiloansA['Last disposition Date'] = ''
df_flexiloansA['Pendency'] = ''
df_flexiloansA['Monthly turn over of merchant'] = ''
df_flexiloansA['Loan Amount Requested'] = df_flexiloansA['Loan Amount']
df_flexiloansA['Sanctioned Amount'] = df_flexiloansA['Sanctioned Amount']
df_flexiloansA['PF Charges'] = df_flexiloansA['Pf Charges']
df_flexiloansA['Doc Charges'] = df_flexiloansA['Doc Charges']
df_flexiloansA['Insurance Charges'] = ''
df_flexiloansA['Net Disbursed Amount'] = df_flexiloansA['Net Disbursed Amount']
df_flexiloansA['Interest Rate'] = df_flexiloansA['Interest Rate']
df_flexiloansA['Interest Rate Type'] = df_flexiloansA['Interest Rate Type']
df_flexiloansA['Tenure'] = df_flexiloansA['Tenure']
df_flexiloansA['Repayment Frequency'] = df_flexiloansA['Repayment Frequency']
df_flexiloansA['Offered Date'] = df_flexiloansA['Post_PD_date']
df_flexiloansA['Disbursed Date'] = df_flexiloansA['Disbursed Date']
df_flexiloansA['Post Sanctioned Status'] = ''
df_flexiloansA['Rejected Reason'] = ''
df_flexiloansA['Offered Amount'] = df_flexiloansA['offered_amount_pd']
df_flexiloansA['Sanction Date'] = df_flexiloansA['Approved Date']
df_flexiloansA['Sanction Amount'] = df_flexiloansA['Sanctioned Amount']

# %%
df_flexiloansI = pd.read_excel(path+'\\FL\\FL.xlsx',sheet_name='In_progress',engine='openpyxl')

# %%
df_flexiloansI.head()
# Out:
#             code                 business_name             application_no  \
# 0  65e6c73egwzqj          S.G.ABHANG PETROLIUM  PNF-MACHA-000-MAR24-00050
# 1  65e55eeb51gt0                ROOP JEWELLERS  PEF-KABEN-000-MAR24-00170
# 2  65d756f67amhb    Sri Guru Kripa Enterprises  PNF-KABEN-000-FEB24-01883
# 3  65d778a4owosn                 Mehta Battery  PEF-UTAVA-000-FEB24-00023
# 4  65e885e1d8zh8  AGRI SCIENCE PRIVATE LIMITED  PNF-MAMUM-000-MAR24-00140
#
#   partner_application_number      lead_code    Created       Hot Lead Date  \
# 0   65e6c6357a7cb89ad74dbccb  65e6c73esyakl 2024-03-05 2024-03-27 12:12:28
# 1   65e320768e0e94bb2443918d  65017e751lqc0 2024-03-04                 NaT
# 2   65216ec70c694df7143afca9  65d756f67k49o 2024-02-22                 NaT
# 3   65d77811c5917ed766e37566  609129c6jefib 2024-02-22                 NaT
# 4                        NaN  65e885e1inxg0 2024-03-06                 NaT
#
#          Post_PD_date  offered_amount_pd  Days Since Lead Created  \
# 0 2024-03-30 17:35:56           670000.0                        0
# 1                 NaT                NaN                        0
# 2                 NaT                NaN                        0
# 3                 NaT                NaN                        0
# 4                 NaT                NaN                        0
#
#    Loan Amount  Total Calls Made  Calls Not Answered Fresh_Top_Up  \
# 0      1500000               110                  98        Fresh
# 1      1000000                97                  93        Fresh
# 2      3025000               127                 119        Fresh
# 3       400000               121                 118        Fresh
# 4        60000                21                  21        Fresh
#
#             s1              s2            s3  \
# 0  In Progress        Hot Lead  Post PD Hold
# 1  In Progress  Qualified Lead  Form Pending
# 2  In Progress  Qualified Lead  Form Pending
# 3  In Progress  Qualified Lead  Form Pending
# 4  In Progress  Qualified Lead  Form Pending
#
#                                    Pending Documents  Pending Document Count  \
# 0  Documents for 'Residential Address Proof'\nOpt...                       3
# 1  Documents for 'Bank statement'\nRequired:\nBan...                       2
# 2  Documents for 'KYC'\nRequired:\nPan Card (Fath...                       6
# 3  Documents for 'Residential Address Proof'\nOpt...                       4
# 4  Documents for 'Residential Address Proof'\nOpt...                       7
#
#    Priority                                      Document_Link       name  \
# 0         1  http://apply.flexiloans.com/?al=true&lm=65e6c7...  Pine Labs
# 1         2  http://apply.flexiloans.com/?al=true&lm=65017e...  Pine Labs
# 2         2  http://apply.flexiloans.com/?al=true&lm=65d756...  Pine Labs
# 3         2  http://apply.flexiloans.com/?al=true&lm=609129...  Pine Labs
# 4         2  http://apply.flexiloans.com/?al=true&lm=65e885...  Pine Labs
#
#   platform        MTO  serviceable   Mobile_no             inserted_on
# 0      Web  1000000.0            1  9511111088 2024-04-01 03:30:09.912
# 1      Web   400000.0            1  6361038810 2024-04-01 03:30:09.912
# 2      Web  1000000.0            1  9972032132 2024-04-01 03:30:09.912
# 3      Web  1000000.0            1  8127482888 2024-04-01 03:30:09.912
# 4      Web   200000.0            1  6789987714 2024-04-01 03:30:09.912

# %%
df_flexiloansI['Customer ID'] = df_flexiloansI['code']
df_flexiloansI['LAN'] = df_flexiloansI['application_no']
df_flexiloansI['Contact No.'] = df_flexiloansI['Mobile_no']
df_flexiloansI['Lender Partner '] = 'Flexi Loan'
df_flexiloansI['Merchant Name '] = ''
df_flexiloansI['Business Name '] = df_flexiloansI['business_name']
df_flexiloansI['Region'] = ''
df_flexiloansI['State'] = ''
df_flexiloansI['City'] = ''
df_flexiloansI['Final Lead Status'] = df_flexiloansI['s2']
df_flexiloansI['Lead Created Date'] = df_flexiloansI['Created']
df_flexiloansI['Lead last Disposition '] = df_flexiloansI['s3']
df_flexiloansI['Last disposition Date'] = ''
df_flexiloansI['Pendency'] = df_flexiloansI['Pending Documents']
df_flexiloansI['Monthly turn over of merchant'] = ''
df_flexiloansI['Loan Amount Requested'] = df_flexiloansI['Loan Amount']
df_flexiloansI['Sanctioned Amount'] = df_flexiloansI['offered_amount_pd']
df_flexiloansI['PF Charges'] = ''
df_flexiloansI['Doc Charges'] = ''
df_flexiloansI['Insurance Charges'] = ''
df_flexiloansI['Net Disbursed Amount'] = ''
df_flexiloansI['Interest Rate'] = ''
df_flexiloansI['Interest Rate Type'] = ''
df_flexiloansI['Tenure'] = ''
df_flexiloansI['Repayment Frequency'] = ''
df_flexiloansI['Offered Date'] = df_flexiloansI['Post_PD_date']
df_flexiloansI['Disbursed Date'] = ''
df_flexiloansI['Post Sanctioned Status'] = ''
df_flexiloansI['Rejected Reason'] = ''
df_flexiloansI['Offered Amount'] = df_flexiloansI['offered_amount_pd']
df_flexiloansI['Sanction Date'] = ''
df_flexiloansI['Sanction Amount'] =''

# %%
df_flexiloansR = pd.read_excel(path+'\\FL\\FL.xlsx',sheet_name='Rejected',engine='openpyxl')

# %%
df_flexiloansR.head()
# Out:
#             code       business_name             application_no  \
# 0  6607df06dnkfp  ISHA PRINT PROCESS  PNF-HAANA-000-MAR24-00070
# 1  65d75833i7nnp       Shivam Mobile  PNF-GUVAR-000-FEB24-00053
# 2  65ccc35db9nog       HAWWA TRADERS  PNF-TAMYL-000-FEB24-00003
# 3  6603e1beo5ikt          MAHI SALES  ANF-GUBHA-000-MAR24-00001
# 4  65fa7bcbdepuk       BAJAJ GALLERY  PEF-PUJAL-000-MAR24-00001
#
#   partner_application_number      lead_code        Post_PD_date  \
# 0                        NaN  6607df068olma                 NaT
# 1   65d755c6c5917ed766e371cb  65d75833gjnlj                 NaT
# 2   65ccc1618b8f581d57f56388  65ccc35dt1eut                 NaT
# 3                        NaN  6603e1beo6uuy 2024-03-29 15:48:51
# 4   65fa7af5842de95d36a3405c  608bf36djqrym                 NaT
#
#    offered_amount_pd    Created       Hot Lead Date  Loan Amount  \
# 0                NaN 2024-03-30                 NaT        50000
# 1                NaN 2024-02-22                 NaT      1500000
# 2                NaN 2024-02-14                 NaT      1050000
# 3                NaN 2024-03-27 2024-03-27 16:02:01      1000000
# 4                NaN 2024-03-20                 NaT       600000
#
#    Total Calls Made  Calls Not Answered  Disbursed Date Approved Date  \
# 0               NaN                 NaN             NaN           NaT
# 1             117.0               102.0             NaN           NaT
# 2             158.0               147.0             NaN           NaT
# 3               4.0                 0.0             NaN           NaT
# 4              60.0                56.0             NaN           NaT
#
#   Fresh_Top_Up            s1                s2  \
# 0        Fresh  Not approved  Lender Rejection
# 1        Fresh  Not approved  Seller Rejection
# 2        Fresh  Not approved  Seller Rejection
# 3        Fresh  Not approved  Seller Rejection
# 4        Fresh  Not approved  Seller Rejection
#
#                                     s3                  Rejection_Reason  \
# 0                        Credit Policy              ["business_vintage"]
# 1                       Not Interested  ["No requirement, Only Enquiry"]
# 2                       Not Interested  ["No requirement, Only Enquiry"]
# 3                  Lost to Competition              ["Delayed response"]
# 4  Required Documentation not Provided             ["Document Required"]
#
#         name       Rejected_Date   platform        MTO  serviceable  \
# 0  Pine Labs 2024-03-30 15:15:08        Web        NaN            0
# 1  Pine Labs 2024-03-30 13:55:48        Web  1000000.0            1
# 2  Pine Labs 2024-03-30 11:20:15        Web  1000000.0            1
# 3  Pine Labs 2024-03-29 19:46:43  loanwiser   800000.0            1
# 4  Pine Labs 2024-03-29 09:31:41        Web   400000.0            1
#
#    approved_amount   Mobile_no             inserted_on
# 0              NaN  9319407415 2024-04-01 03:30:09.912
# 1              NaN  9687000873 2024-04-01 03:30:09.912
# 2              NaN  9600026435 2024-04-01 03:30:09.912
# 3              NaN  9574336969 2024-04-01 03:30:09.912
# 4              NaN  7508092882 2024-04-01 03:30:09.912

# %%
df_flexiloansR['Customer ID'] = df_flexiloansR['code']
df_flexiloansR['LAN'] = df_flexiloansR['application_no']
df_flexiloansR['Contact No.'] = df_flexiloansR['Mobile_no']
df_flexiloansR['Lender Partner '] = 'Flexi Loan'
df_flexiloansR['Merchant Name '] = ''
df_flexiloansR['Business Name '] = df_flexiloansR['business_name']
df_flexiloansR['Region'] = ''
df_flexiloansR['State'] = ''
df_flexiloansR['City'] = ''
df_flexiloansR['Final Lead Status'] = df_flexiloansR['s1']
df_flexiloansR['Lead Created Date'] = df_flexiloansR['Created']
df_flexiloansR['Lead last Disposition '] = df_flexiloansR['s3']
df_flexiloansR['Last disposition Date'] = ''
df_flexiloansR['Pendency'] = ''
df_flexiloansR['Monthly turn over of merchant'] = ''
df_flexiloansR['Loan Amount Requested'] = df_flexiloansR['Loan Amount']
df_flexiloansR['Sanctioned Amount'] = df_flexiloansR['offered_amount_pd']
df_flexiloansR['PF Charges'] = ''
df_flexiloansR['Doc Charges'] = ''
df_flexiloansR['Insurance Charges'] = ''
df_flexiloansR['Net Disbursed Amount'] = ''
df_flexiloansR['Interest Rate'] = ''
df_flexiloansR['Interest Rate Type'] = ''
df_flexiloansR['Tenure'] = ''
df_flexiloansR['Repayment Frequency'] = ''
df_flexiloansR['Offered Date'] = df_flexiloansR['Post_PD_date']
df_flexiloansR['Disbursed Date'] = ''
df_flexiloansR['Post Sanctioned Status'] = ''
df_flexiloansR['Rejected Reason'] = np.where(df_flexiloansR['s1']=='Not approved',df_flexiloansR['s2']+" & " + df_flexiloansR['s3'],"")
df_flexiloansR['Offered Amount'] = df_flexiloansR['offered_amount_pd']
df_flexiloansR['Sanction Date'] = df_flexiloansR['Approved Date']
df_flexiloansR['Sanction Amount'] = np.where(~df_flexiloansR['Sanction Date'].isnull(),df_flexiloansR['offered_amount_pd'],0)

# %%
df_LK_final = df_lendingkart[['Customer ID', 'LAN',
       'Contact No.', 'Lender Partner ', 'Merchant Name ', 'Business Name ',
       'Region', 'State', 'City', 'Final Lead Status', 'Lead Created Date',
       'Lead last Disposition ', 'Last disposition Date', 'Pendency',
       'Monthly turn over of merchant', 'Loan Amount Requested',
       'Sanctioned Amount', 'PF Charges', 'Doc Charges', 'Insurance Charges',
       'Net Disbursed Amount', 'Interest Rate', 'Interest Rate Type', 'Tenure',
       'Repayment Frequency', 'Offered Date', 'Disbursed Date',
       'Post Sanctioned Status', 'Rejected Reason','Offered Amount','Sanction Date','Sanction Amount']]

# %%
df_FLA = df_flexiloansA[['Customer ID', 'LAN',
       'Contact No.', 'Lender Partner ', 'Merchant Name ', 'Business Name ',
       'Region', 'State', 'City', 'Final Lead Status', 'Lead Created Date',
       'Lead last Disposition ', 'Last disposition Date', 'Pendency',
       'Monthly turn over of merchant', 'Loan Amount Requested',
       'Sanctioned Amount', 'PF Charges', 'Doc Charges', 'Insurance Charges',
       'Net Disbursed Amount', 'Interest Rate', 'Interest Rate Type', 'Tenure',
       'Repayment Frequency', 'Offered Date', 'Disbursed Date',
       'Post Sanctioned Status', 'Rejected Reason','Offered Amount','Sanction Date','Sanction Amount']]

# %%
df_FLR = df_flexiloansR[['Customer ID', 'LAN',
       'Contact No.', 'Lender Partner ', 'Merchant Name ', 'Business Name ',
       'Region', 'State', 'City', 'Final Lead Status', 'Lead Created Date',
       'Lead last Disposition ', 'Last disposition Date', 'Pendency',
       'Monthly turn over of merchant', 'Loan Amount Requested',
       'Sanctioned Amount', 'PF Charges', 'Doc Charges', 'Insurance Charges',
       'Net Disbursed Amount', 'Interest Rate', 'Interest Rate Type', 'Tenure',
       'Repayment Frequency', 'Offered Date', 'Disbursed Date',
       'Post Sanctioned Status', 'Rejected Reason','Offered Amount','Sanction Date','Sanction Amount']]

# %%
df_FLI = df_flexiloansI[['Customer ID', 'LAN',
       'Contact No.', 'Lender Partner ', 'Merchant Name ', 'Business Name ',
       'Region', 'State', 'City', 'Final Lead Status', 'Lead Created Date',
       'Lead last Disposition ', 'Last disposition Date', 'Pendency',
       'Monthly turn over of merchant', 'Loan Amount Requested',
       'Sanctioned Amount', 'PF Charges', 'Doc Charges', 'Insurance Charges',
       'Net Disbursed Amount', 'Interest Rate', 'Interest Rate Type', 'Tenure',
       'Repayment Frequency', 'Offered Date', 'Disbursed Date',
       'Post Sanctioned Status', 'Rejected Reason','Offered Amount','Sanction Date','Sanction Amount']]

# %%
df_FL_final = df_FLA.append(df_FLR).append(df_FLI)

# %%
df_FL_final.head()
# Out:
#      Customer ID                        LAN  Contact No. Lender Partner   \
# 0  65c60fcdgydn5  PEF-UTCAN-000-FEB24-00004   9793807225      Flexi Loan
# 1  65d78394b7z7f  PEF-UTGYA-000-FEB24-00011   8057367368      Flexi Loan
# 2  65d9d492bscg9  PEF-GUDAH-000-FEB24-00016   9727021890      Flexi Loan
# 3  65b63bbbfbalc  PEF-DESOU-000-JAN24-00012   9990876005      Flexi Loan
# 4  65c5fbcbhkyv5  PNF-UTIQB-000-FEB24-00001   9012912019      Flexi Loan
#
#   Merchant Name             Business Name  Region State City  \
# 0                          M/S LIBAS MAHAL
# 1                            KRISHNA SALES
# 2                       SIDDHI ELECTRONICS
# 3                        AHIBIA COLLECTION
# 4                 AL LIMRA AIR CONDITIONER
#
#   Final Lead Status Lead Created Date Lead last Disposition   \
# 0         Disbursed        2024-02-09                   None
# 1         Disbursed        2024-02-22                   None
# 2         Disbursed        2024-02-24                   None
# 3         Disbursed        2024-01-28                   None
# 4         Disbursed        2024-02-09                   None
#
#   Last disposition Date Pendency Monthly turn over of merchant  \
# 0
# 1
# 2
# 3
# 4
#
#    Loan Amount Requested  Sanctioned Amount PF Charges Doc Charges  \
# 0                 500000           210000.0       4.13        7080
# 1                1000000          1000000.0       2.95        7080
# 2                1000000           500000.0       2.95        5900
# 3                2500000          1500000.0       2.36        5900
# 4                1000000           285000.0       2.36        5900
#
#   Insurance Charges Net Disbursed Amount Interest Rate Interest Rate Type  \
# 0                               186630.2           1.5               Flat
# 1                               938243.0           1.3               Flat
# 2                               479016.0           1.0               Flat
# 3                              1450450.0           1.5           Variable
# 4                               270344.0           1.3               Flat
#
#   Tenure Repayment Frequency        Offered Date       Disbursed Date  \
# 0     24              Months 2024-02-10 18:30:41  2024-02-13 00:00:00
# 1     30              Months 2024-02-24 13:40:32  2024-02-27 00:00:00
# 2     36              Months 2024-02-25 15:13:24  2024-02-29 00:00:00
# 3     36              Months 2024-01-29 17:08:03  2024-02-13 00:00:00
# 4     24              Months 2024-02-10 15:56:15  2024-03-08 00:00:00
#
#   Post Sanctioned Status Rejected Reason  Offered Amount        Sanction Date  \
# 0                                               210000.0  2024-02-13 13:29:33
# 1                                              1000000.0  2024-02-24 22:51:05
# 2                                               500000.0  2024-02-27 13:05:48
# 3                                              1000000.0  2024-02-09 20:14:20
# 4                                               285000.0  2024-02-23 20:17:57
#
#   Sanction Amount
# 0        210000.0
# 1       1000000.0
# 2        500000.0
# 3       1500000.0
# 4        285000.0

# %%
df_FL_final['Contact No.'].nunique()
# Out:
# 746

# %%
df_FL_final.shape
# Out:
# (884, 32)

# %%
df_FL_final['Lead Created Date']=df_FL_final['Lead Created Date'].astype('datetime64[ns]')

# %%
df_FL_final['Lead Created Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df_LK_final['Lead Created Date']=df_LK_final['Lead Created Date'].astype('datetime64[ns]')

# %%
df_LK_final['Offered Date']=df_LK_final['Offered Date'].astype('datetime64[ns]')

# %%
df_LK_final['Sanction Date']=df_LK_final['Sanction Date'].astype('datetime64[ns]')

# %%
df_FL_final['Sanctioned Amount'].dtype
# Out:
# dtype('float64')

# %%
df_LK_final['Lead Created Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df_LK_final['Sanction Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df_LK_final['Offered Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df_flexiloansR['Offered Amount'].dtype
# Out:
# dtype('float64')

# %%
#df_flexiloansR['Offered Amount']=df_flexiloansR['Offered Amount'].replace('',0).astype(int)
df_flexiloansR['Offered Amount']= df_flexiloansR['Offered Amount'].fillna(value=0)
df_flexiloansR['Offered Amount'].astype(int)
# Out:
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
#         ...
# 807         0
# 808    370000
# 809         0
# 810         0
# 811         0
# Name: Offered Amount, Length: 812, dtype: int32

# %%
#pd.to_numeric(df_FL_final['Sanctioned Amount'], errors="ignore")
df_FL_final['Sanctioned Amount']=df_FL_final['Sanctioned Amount'].fillna(value=0).astype(int)
df_FL_final['Sanctioned Amount'].dtype
# Out:
# dtype('int32')

# %%
#df_FL_final = df_FL_final.sort_values(by=['Contact No.','Lead Created Date'],ascending=[False,False])

# %%
df_LK_final['Disbursed Date'].dtype
df_LK_final['Disbursed Date']=pd.to_datetime(df_LK_final['Disbursed Date'])
df_LK_final['Disbursed Date'].dtype
df_FL_final['Disbursed Date'].dtype
df_FL_final['Disbursed Date']=pd.to_datetime(df_FL_final['Disbursed Date'])
df_FL_final['Disbursed Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df_FL_final['Sanction Date']=pd.to_datetime(df_FL_final['Sanction Date'])
df_FL_final['Sanction Date'].dtype
df_LK_final['Sanction Date']=pd.to_datetime(df_LK_final['Sanction Date'])
df_LK_final['Sanction Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
#df_FL_final['Sanction Amount']=df_FL_final['Sanction Amount'].fillna(value=0).astype(float)
#df_FL_final['Sanction Amount'].astype(int)
df_FL_final['Sanction Amount'].replace('',0).astype(float)
df_FL_final['Sanction Amount'].dtype
# Out:
# dtype('O')

# %%
#df_LK_final = df_LK_final.sort_values(by=['Contact No.','Lead Created Date'],ascending=[False,False])

# %%
df_FL_final = df_FL_final.sort_values(by=['Contact No.','Lead Created Date'],ascending=[False,False])

# %%
df_LK_final = df_LK_final.sort_values(by=['Contact No.','Lead Created Date'],ascending=[False,False])

# %%
T = str(((date.today()).strftime("%Y%m%d")))

# %%
df_Final = df_FL_final.append(df_LK_final)

# %%
#df_Final['Lead Created Date'] =pd.todatetime(df_Final['Lead Created Date'],format="%Y:%M:%D")

# %%
#df_Final = df_Final.sort_values(by=['Contact No.','Lead Created Date'],ascending=[True,True])

# %%
#adding dicsionary to add one column (Reverse Mapping)
Mapping_dictionary ={'Agreement Signed' : 'Approved' , 'Agreement Stage' : 'Approved' , 'Application in Progress' : 'InComplete Appl' ,'Application Rejected': 'Reject', 'Application under Evaluation' : 'In Process' , 'Approved' : 'Approved' , 
'Closed': 'Reject' , 'Disbursed': 'Disbursed' , 'Fresh Lead': 'New Lead', 'Hot Lead': 'In Process',
 'Not approved':'Reject' ,'Qualified Lead': 'InComplete Appl' ,'Terms & Conditions Stage' : 'Approved'}

#df_Final['Final Status'] = df_Final['Final Lead Status'].map(Mapping_dictionary)

df_Final['Final Status'] = np.where(df_Final['Lead last Disposition ']== "Not Started", 'New Lead',df_Final['Final Lead Status'].map(Mapping_dictionary))
df_Final['Final Status'] = np.where(df_Final['Lead last Disposition ']== "Post PD Hold", 'Approved',df_Final['Final Lead Status'].map(Mapping_dictionary))
#df_Final['Sanctioned Amount']=df_Final['Sanctioned Amount'].astype(int)
df_Final['Approved Amount']=df_Final['Sanctioned Amount'].div(100000).round(3)

# %%
#df_Final['Count']=df_Final.groupby(['Contact No.','Lender Partner '])[['Contact No.']].count()

# %%
df_Final.head()
# Out:
#        Customer ID                        LAN   Contact No. Lender Partner   \
# 25   65bcd780julvd  PEF-DEHAS-000-FEB24-00006  9.999401e+09      Flexi Loan
# 799  65bdf53aydgnq  PNF-HAANA-000-FEB24-00004  9.999204e+09      Flexi Loan
# 136  65f830dbin3k1  PEF-GUKHA-000-MAR24-00012  9.998520e+09      Flexi Loan
# 652  65ca2328la5sp  PEF-GUCHA-000-FEB24-00034  9.998007e+09      Flexi Loan
# 654  65ca22e74qald  PEF-GUTHA-000-FEB24-00012  9.998007e+09      Flexi Loan
#
#     Merchant Name                  Business Name  Region State City  \
# 25                            Primex Laboratories
# 799                 MOHD NASEEM AHMED BOOK BINDER
# 136                             STEELHERD FITNESS
# 652                                           NaN
# 654                             RAPID MOBILE CARE
#
#     Final Lead Status Lead Created Date Lead last Disposition   \
# 25          Disbursed        2024-02-02                   None
# 799      Not approved        2024-02-03         Not Interested
# 136      Not approved        2024-03-18          Credit Policy
# 652      Not approved        2024-02-12          Credit Policy
# 654      Not approved        2024-02-12          Credit Policy
#
#     Last disposition Date Pendency Monthly turn over of merchant  \
# 25
# 799
# 136
# 652
# 654
#
#      Loan Amount Requested  Sanctioned Amount PF Charges Doc Charges  \
# 25                  400000           500000.0       2.95        5900
# 799                  50000                0.0
# 136                 825000                0.0
# 652                  50000                0.0
# 654                 750000                0.0
#
#     Insurance Charges Net Disbursed Amount Interest Rate Interest Rate Type  \
# 25                                465597.0           1.5               Flat
# 799
# 136
# 652
# 654
#
#     Tenure Repayment Frequency Offered Date Disbursed Date  \
# 25      30              Months          NaT     2024-02-08
# 799                                     NaT            NaT
# 136                                     NaT            NaT
# 652                                     NaT            NaT
# 654                                     NaT            NaT
#
#     Post Sanctioned Status                    Rejected Reason  Offered Amount  \
# 25                                                                        NaN
# 799                         Seller Rejection & Not Interested             NaN
# 136                          Lender Rejection & Credit Policy             NaN
# 652                          Lender Rejection & Credit Policy             NaN
# 654                          Lender Rejection & Credit Policy             NaN
#
#           Sanction Date Sanction Amount Final Status  Approved Amount
# 25  2024-02-07 13:22:27        500000.0    Disbursed              5.0
# 799                 NaT             0.0       Reject              0.0
# 136                 NaT             0.0       Reject              0.0
# 652                 NaT             0.0       Reject              0.0
# 654                 NaT             0.0       Reject              0.0

# %%
df_Final.dtypes
# Out:
# Customer ID                              object
# LAN                                      object
# Contact No.                             float64
# Lender Partner                           object
# Merchant Name                            object
# Business Name                            object
# Region                                   object
# State                                    object
# City                                     object
# Final Lead Status                        object
# Lead Created Date                datetime64[ns]
# Lead last Disposition                    object
# Last disposition Date                    object
# Pendency                                 object
# Monthly turn over of merchant            object
# Loan Amount Requested                     int64
# Sanctioned Amount                       float64
# PF Charges                               object
# Doc Charges                              object
# Insurance Charges                        object
# Net Disbursed Amount                     object
# Interest Rate                            object
# Interest Rate Type                       object
# Tenure                                   object
# Repayment Frequency                      object
# Offered Date                     datetime64[ns]
# Disbursed Date                   datetime64[ns]
# Post Sanctioned Status                   object
# Rejected Reason                          object
# Offered Amount                          float64
# Sanction Date                    datetime64[ns]
# Sanction Amount                          object
# Final Status                             object
# Approved Amount                         float64
# dtype: object

# %%
df_Indifi= pd.read_csv(path+'\\Indifi\\applications.csv')

# %%
df_Indifi.head()
# Out:
#    request_id                                    id  \
# 0     7690681  89c15a84-0ec0-4495-8ed2-f03070c651a0
# 1     7690417  f7426188-0407-4da7-860f-a816742ceef3
# 2     7678581  32c9e8b9-0280-4199-8be1-54991b201342
# 3     7671909  023f2e14-9a8f-4e9b-ac83-0fb4cfaa7bde
# 4     7671777  d089dd6a-aa5c-4fa6-87af-d80bcb052b3d
#
#                                name         phone  \
# 0                   SAI BOOK CENTER  7.028206e+09
# 1                   SAI BOOK CENTER  9.766086e+09
# 2                          I MOBILE  9.827304e+09
# 3                 LOGASS BUILDSWARE  9.844689e+09
# 4  FORU MARKETPLACE PRIVATE LIMITED  8.240410e+09
#
#                 anchor_unique_id    anchor               city        location  \
# 0                            NaN  Pinelabs                NaN             NaN
# 1                            NaN  Pinelabs                NaN             NaN
# 2  {00,66040dbba38ab4942fb43721}  Pinelabs           Jabalpur  Madhya Pradesh
# 3                           {00}  Pinelabs             Mysore       Karnataka
# 4     {66039d4ca38ab4942fb43662}  Pinelabs  North 24 Parganas     West Bengal
#
#    applied_amount       state   lead_date lead_time application_date  \
# 0        200000.0    Rejected  29-03-2024     10:09       29-03-2024
# 1        500000.0    Rejected  29-03-2024     08:51       29-03-2024
# 2             NaN  Incomplete  27-03-2024     06:15       27-03-2024
# 3       3000000.0  Incomplete  27-03-2024     10:07       27-03-2024
# 4       3000000.0    Rejected  27-03-2024     09:46       27-03-2024
#
#   application_time  sanction_amount sanction_date sanction_time  \
# 0            10:29              NaN           NaN           NaN
# 1            08:30              NaN           NaN           NaN
# 2            06:23              NaN           NaN           NaN
# 3            10:07              NaN           NaN           NaN
# 4            09:46              NaN           NaN           NaN
#
#    disbursed_amount disbursed_date disbursed_time  interest_rate  \
# 0               NaN            NaN            NaN            NaN
# 1               NaN            NaN            NaN            NaN
# 2               NaN            NaN            NaN            NaN
# 3               NaN            NaN            NaN            NaN
# 4               NaN            NaN            NaN            NaN
#
#    processing_fee rejection_date rejection_time        rejection_reason  \
# 0             NaN     29-03-2024          10:11  Credit Risk Assessment
# 1             NaN     29-03-2024          08:05  Credit Risk Assessment
# 2             NaN            NaN            NaN                     NaN
# 3             NaN            NaN            NaN                     NaN
# 4             NaN     29-03-2024          10:33  Credit Risk Assessment
#
#   utm_source utm_campaign utm_medium  is_renewed business_nature  \
# 0       '---         '---       '---       False             NaN
# 1       '---         '---       '---       False             NaN
# 2       '---         '---       '---       False         Trading
# 3       '---         '---       '---       False         Trading
# 4       '---         '---       '---       False          Retail
#
#    anchor_applicationid application_completion_date  \
# 0                   NaN                         NaN
# 1                   NaN                         NaN
# 2                   NaN                         NaN
# 3                   NaN                  28-03-2024
# 4                   NaN                         NaN
#
#   application_completion_time  is_womenled fast_loan_link rejection_code  \
# 0                         NaN          NaN             '-  credit_reject
# 1                         NaN          NaN             '-  credit_reject
# 2                         NaN          NaN             '-            NaN
# 3                       12:52          NaN             '-            NaN
# 4                         NaN          NaN             '-  credit_reject
#
#    dsa_agent_id offer_made_date  offer_amount
# 0           NaN             NaN           NaN
# 1           NaN             NaN           NaN
# 2           NaN             NaN           NaN
# 3           NaN             NaN           NaN
# 4           NaN             NaN           NaN

# %%
df_Indifi.columns
# Out:
# Index(['request_id', 'id', 'name', 'phone', 'anchor_unique_id', 'anchor',
#        'city', 'location', 'applied_amount', 'state', 'lead_date', 'lead_time',
#        'application_date', 'application_time', 'sanction_amount',
#        'sanction_date', 'sanction_time', 'disbursed_amount', 'disbursed_date',
#        'disbursed_time', 'interest_rate', 'processing_fee', 'rejection_date',
#        'rejection_time', 'rejection_reason', 'utm_source', 'utm_campaign',
#        'utm_medium', 'is_renewed', 'business_nature', 'anchor_applicationid',
#        'application_completion_date', 'application_completion_time',
#        'is_womenled', 'fast_loan_link', 'rejection_code', 'dsa_agent_id',
#        'offer_made_date', 'offer_amount'],
#       dtype='object')

# %%
df_Indifi.dtypes
# Out:
# request_id                       int64
# id                              object
# name                            object
# phone                          float64
# anchor_unique_id                object
# anchor                          object
# city                            object
# location                        object
# applied_amount                 float64
# state                           object
# lead_date                       object
# lead_time                       object
# application_date                object
# application_time                object
# sanction_amount                float64
# sanction_date                   object
# sanction_time                   object
# disbursed_amount               float64
# disbursed_date                  object
# disbursed_time                  object
# interest_rate                  float64
# processing_fee                 float64
# rejection_date                  object
# rejection_time                  object
# rejection_reason                object
# utm_source                      object
# utm_campaign                    object
# utm_medium                      object
# is_renewed                        bool
# business_nature                 object
# anchor_applicationid           float64
# application_completion_date     object
# application_completion_time     object
# is_womenled                    float64
# fast_loan_link                  object
# rejection_code                  object
# dsa_agent_id                   float64
# offer_made_date                 object
# offer_amount                   float64
# dtype: object

# %%
df_Indifi[df_Indifi['disbursed_date'].notnull()].head(10)
# Out:
#      request_id                                    id  \
# 7       7669163  49463f27-be7f-4991-a1f7-c61bb0238f97
# 23      7654668  4a5d7511-52a1-470f-85d8-f58177f060c9
# 53      7613998  ecaeef87-589a-4577-b0e5-afa85dec8aa8
# 91      7571669  95890f41-905c-4c2c-afad-6b6ccad6bd7e
# 136     7526160  db8719e8-7862-46c1-9290-5aa62a8b9a47
# 165     7504581  0cc91401-7785-42cc-b4f2-e22b2de4c6ef
# 230     7399605  6820943a-fb68-4c49-839e-30e442d143a7
# 243     7380049  65d7e721-75ad-4e46-9169-3a672edb418a
# 248     7372956  81eb0e92-6732-4d32-a6e5-4f7ed3b42bb3
# 268     7361569  98da87e2-8736-4ca4-8ee6-47469a4b84ab
#
#                                           name         phone  \
# 7                                   MAHI SALES  9.574337e+09
# 23                      The interior solutions  9.540331e+09
# 53                            SRI VARI TRADERS  9.945986e+09
# 91                Mobile Campus and Electronic  7.088332e+09
# 136  RIQUEZA ELECTRIC VEHICLES PRIVATE LIMITED  9.821448e+09
# 165                                 SK TRADING  9.506576e+09
# 230            MEDOC CLOTHINGS PRIVATE LIMITED  9.574823e+09
# 243                                  VANI OILS  9.951775e+09
# 248                     Guru Kripa Electronics  9.896798e+09
# 268                          LIONS KARATE CLUB  9.099752e+09
#
#                   anchor_unique_id    anchor          city        location  \
# 7                              NaN  Pinelabs  Panch Mahals         Gujarat
# 23                             NaN  Pinelabs       Gurgaon         Haryana
# 53                            {00}  Pinelabs     Bangalore       Karnataka
# 91                            {00}  Pinelabs      Haridwar     Uttarakhand
# 136                           {00}  Pinelabs         Thane     Maharashtra
# 165                           {00}  Pinelabs     Gorakhpur   Uttar Pradesh
# 230                           {00}  Pinelabs        Valsad         Gujarat
# 243                           {00}  Pinelabs       Nellore  Andhra Pradesh
# 248                           {00}  Pinelabs       Sonipat         Haryana
# 268  {00,65339cd3fdb2e2a2ec9fd556}  Pinelabs      Jamnagar         Gujarat
#
#      applied_amount        state   lead_date lead_time application_date  \
# 7          750000.0  Loan Active  26-03-2024     03:53       26-03-2024
# 23        1000000.0  Loan Active  22-03-2024     05:23       22-03-2024
# 53        1000000.0  Loan Active  18-03-2024     06:37       18-03-2024
# 91        1500000.0  Loan Active  12-03-2024     06:44       12-03-2024
# 136        160000.0  Loan Active  07-03-2024     04:58       07-03-2024
# 165       1500000.0  Loan Active  05-03-2024     06:52       05-03-2024
# 230        145000.0  Loan Active  26-02-2024     03:57       26-02-2024
# 243        983000.0  Loan Active  24-02-2024     12:12       24-02-2024
# 248        444000.0  Loan Active  23-02-2024     03:11       23-02-2024
# 268        431000.0  Loan Active  22-02-2024     02:36       22-02-2024
#
#     application_time  sanction_amount sanction_date sanction_time  \
# 7              03:27         761595.0    27-03-2024         01:34
# 23             05:23        1015460.0    26-03-2024         07:32
# 53             06:10        1015460.0    21-03-2024         02:47
# 91             06:44         246843.0    15-03-2024         04:58
# 136            04:58         160000.0    16-03-2024         12:32
# 165            06:18         323180.0    13-03-2024         04:13
# 230            04:16         147241.0    01-03-2024         01:22
# 243            12:24         998197.0    29-02-2024         01:01
# 248            03:30         450864.0    24-02-2024         10:03
# 268            02:36         334277.0    23-02-2024         11:41
#
#      disbursed_amount disbursed_date disbursed_time  interest_rate  \
# 7            761595.0     28-03-2024          07:10           24.0
# 23          1015460.0     28-03-2024          08:13           23.0
# 53          1015460.0     27-03-2024          10:34           25.0
# 91           246843.0     19-03-2024          02:12           31.0
# 136          160000.0     27-03-2024          05:00           32.0
# 165          323180.0     16-03-2024          04:41           33.0
# 230          147241.0     14-03-2024          12:28           34.0
# 243          998197.0     29-02-2024          05:00           33.0
# 248          450864.0     27-02-2024          02:25           32.0
# 268          334277.0     26-02-2024          01:37           32.0
#
#      processing_fee rejection_date rejection_time rejection_reason utm_source  \
# 7          29566.64            NaN            NaN              NaN       '---
# 23         51404.62            NaN            NaN              NaN       '---
# 53         29956.07            NaN            NaN              NaN       '---
# 91          8738.24            NaN            NaN              NaN       '---
# 136         8477.12            NaN            NaN              NaN       '---
# 165        11440.57            NaN            NaN              NaN       '---
# 230         5716.19            NaN            NaN              NaN       '---
# 243        50530.73            NaN            NaN              NaN       '---
# 248        22823.64            NaN            NaN              NaN       '---
# 268        11833.41            NaN            NaN              NaN       '---
#
#     utm_campaign utm_medium  is_renewed business_nature  anchor_applicationid  \
# 7           '---       '---       False         Trading                   NaN
# 23          '---       '---       False         Service                   NaN
# 53          '---       '---       False          Retail                   NaN
# 91          '---       '---       False         Trading                   NaN
# 136         '---       '---       False         Trading                   NaN
# 165         '---       '---       False          Retail                   NaN
# 230         '---       '---       False          Retail                   NaN
# 243         '---       '---       False         Trading                   NaN
# 248         '---       '---       False         Trading                   NaN
# 268         '---       '---       False         Service                   NaN
#
#     application_completion_date application_completion_time  is_womenled  \
# 7                    26-03-2024                       06:22          NaN
# 23                   22-03-2024                       05:43          NaN
# 53                   19-03-2024                       06:45          NaN
# 91                   13-03-2024                       11:27          NaN
# 136                  13-03-2024                       10:18          NaN
# 165                  13-03-2024                       03:38          NaN
# 230                  28-02-2024                       10:52          NaN
# 243                  28-02-2024                       05:00          NaN
# 248                  23-02-2024                       04:37          NaN
# 268                  23-02-2024                       10:23          NaN
#
#     fast_loan_link rejection_code  dsa_agent_id offer_made_date  offer_amount
# 7               '-            NaN           NaN      27-03-2024      761595.0
# 23              '-            NaN           NaN      22-03-2024     1015460.0
# 53              '-            NaN           NaN      20-03-2024     1015460.0
# 91              '-            NaN           NaN      13-03-2024      246843.0
# 136             '-            NaN           NaN      15-03-2024      160000.0
# 165             '-            NaN           NaN      13-03-2024      323180.0
# 230             '-            NaN           NaN      29-02-2024      147241.0
# 243             '-            NaN           NaN      29-02-2024      998197.0
# 248             '-            NaN           NaN      23-02-2024      450864.0
# 268             '-            NaN           NaN      23-02-2024      334277.0

# %%
Mapping_dictionary_Indifi ={'Documentation Pending' : 'Approved' , 'Incomplete' : 'InComplete Appl' , 'Loan Active' : 'Disbursed' ,'Offer Acceptance Pending': 'Approved', 'Processing For Offer' : 'In Process' , 'Rejected' : 'Reject' , 
'Withdrawn': 'Reject','Ready To Disburse':'Approved','Under Review For Offer':'In Process'}

# %%
df_Indifi['Customer ID'] = df_Indifi['anchor_unique_id']
df_Indifi['LAN'] = df_Indifi['request_id']
df_Indifi['Contact No.'] = df_Indifi['phone']
df_Indifi['Lender Partner '] = 'INDIFI'
df_Indifi['Merchant Name '] = ''
df_Indifi['Business Name '] = df_Indifi['name']
df_Indifi['Region'] = ''
df_Indifi['State'] = df_Indifi['location']
df_Indifi['City'] = df_Indifi['city']
df_Indifi['Final Lead Status'] =df_Indifi['state']
df_Indifi['Lead Created Date'] = df_Indifi['lead_date']
df_Indifi['Lead last Disposition '] =df_Indifi['state']
df_Indifi['Last disposition Date'] =df_Indifi['application_completion_date']
df_Indifi['Pendency'] =''
df_Indifi['Monthly turn over of merchant'] = ''
df_Indifi['Loan Amount Requested'] = df_Indifi['applied_amount']
df_Indifi['Sanctioned Amount'] =df_Indifi['offer_amount']
df_Indifi['PF Charges'] =''
df_Indifi['Doc Charges'] = ''
df_Indifi['Insurance Charges'] = ''
df_Indifi['Net Disbursed Amount'] =df_Indifi['disbursed_amount']
df_Indifi['Interest Rate'] = df_Indifi['interest_rate']
df_Indifi['Interest Rate Type'] = ''
df_Indifi['Tenure'] =''
df_Indifi['Repayment Frequency'] = ''
df_Indifi['Offered Date'] =df_Indifi['offer_made_date']
df_Indifi['Disbursed Date'] =df_Indifi['disbursed_date']
df_Indifi['Post Sanctioned Status'] = ''
df_Indifi['Rejected Reason'] =df_Indifi['rejection_reason']
df_Indifi['Final Status']=df_Indifi['state'].map(Mapping_dictionary_Indifi)
df_Indifi['Sanctioned Amount'] = pd.to_numeric(df_Indifi['Sanctioned Amount'], errors='coerce')
df_Indifi['Approved Amount']=df_Indifi['Sanctioned Amount'].div(100000).round(3)
df_Indifi['lead_time']=df_Indifi['lead_time']
df_Indifi['Offered Amount'] = df_Indifi['offer_amount']
df_Indifi['Sanction Date'] = df_Indifi['sanction_date']
df_Indifi['Sanction Amount'] = df_Indifi['sanction_amount']

# %%
df_Indifi_final=df_Indifi[['Customer ID', 'LAN',
       'Contact No.', 'Lender Partner ', 'Merchant Name ', 'Business Name ',
       'Region', 'State', 'City', 'Final Lead Status', 'Lead Created Date',
       'Lead last Disposition ', 'Last disposition Date', 'Pendency',
       'Monthly turn over of merchant', 'Loan Amount Requested',
       'Sanctioned Amount', 'PF Charges', 'Doc Charges', 'Insurance Charges',
       'Net Disbursed Amount', 'Interest Rate', 'Interest Rate Type', 'Tenure',
       'Repayment Frequency', 'Offered Date', 'Disbursed Date',
       'Post Sanctioned Status', 'Rejected Reason','Final Status','Approved Amount','Offered Amount','Sanction Date','Sanction Amount','lead_time']]

# %%
df_Indifi_final.dtypes
# Out:
# Customer ID                       object
# LAN                                int64
# Contact No.                      float64
# Lender Partner                    object
# Merchant Name                     object
# Business Name                     object
# Region                            object
# State                             object
# City                              object
# Final Lead Status                 object
# Lead Created Date                 object
# Lead last Disposition             object
# Last disposition Date             object
# Pendency                          object
# Monthly turn over of merchant     object
# Loan Amount Requested            float64
# Sanctioned Amount                float64
# PF Charges                        object
# Doc Charges                       object
# Insurance Charges                 object
# Net Disbursed Amount             float64
# Interest Rate                    float64
# Interest Rate Type                object
# Tenure                            object
# Repayment Frequency               object
# Offered Date                      object
# Disbursed Date                    object
# Post Sanctioned Status            object
# Rejected Reason                   object
# Final Status                      object
# Approved Amount                  float64
# Offered Amount                   float64
# Sanction Date                     object
# Sanction Amount                  float64
# lead_time                         object
# dtype: object

# %%
#df_Indifi_final['Disbursed Date']=df_Indifi_final['Disbursed Date'].astype('datetime64[ns]')

# %%
df_Indifi_final['Disbursed Date'] = pd.to_datetime(df_Indifi_final['Disbursed Date'].str.slice(6,10)+'-'+df_Indifi_final['Disbursed Date'].str.slice(3,5)+'-'+df_Indifi_final['Disbursed Date'].str.slice(0,2))

# %%
df_Indifi_final['Disbursed Date']=pd.to_datetime(df_Indifi_final['Disbursed Date'], errors='coerce')

# %%
df_Indifi_final['Lead Created Date'] = pd.to_datetime(df_Indifi_final['Lead Created Date'].str.slice(6,10)+'-'+df_Indifi_final['Lead Created Date'].str.slice(3,5)+'-'+df_Indifi_final['Lead Created Date'].str.slice(0,2))

# %%
df_Indifi_final['Lead Created Date']=pd.to_datetime(df_Indifi_final['Lead Created Date'], errors='coerce')

# %%
df_Indifi_final['Offered Date'] = pd.to_datetime(df_Indifi_final['Offered Date'].str.slice(6,10)+'-'+df_Indifi_final['Offered Date'].str.slice(3,5)+'-'+df_Indifi_final['Offered Date'].str.slice(0,2))

# %%
df_Indifi_final['Offered Date']=pd.to_datetime(df_Indifi_final['Offered Date'], errors='coerce')

# %%
df_Indifi_final['Sanction Date'] = pd.to_datetime(df_Indifi_final['Sanction Date'].str.slice(6,10)+'-'+df_Indifi_final['Sanction Date'].str.slice(3,5)+'-'+df_Indifi_final['Sanction Date'].str.slice(0,2))

# %%
df_Indifi_final['Sanction Date']=pd.to_datetime(df_Indifi_final['Sanction Date'], errors='coerce')

# %%
df_Indifi_final['Loan Amount Requested']=df_Indifi_final['Loan Amount Requested'].astype('Int64',errors='ignore')

# %%
df_Indifi_final['Net Disbursed Amount']=df_Indifi_final['Net Disbursed Amount'].astype(object)

# %%
df_Indifi_final['Interest Rate']=df_Indifi_final['Interest Rate'].astype(object)

# %%
df_Indifi_final.dtypes
# Out:
# Customer ID                              object
# LAN                                       int64
# Contact No.                             float64
# Lender Partner                           object
# Merchant Name                            object
# Business Name                            object
# Region                                   object
# State                                    object
# City                                     object
# Final Lead Status                        object
# Lead Created Date                datetime64[ns]
# Lead last Disposition                    object
# Last disposition Date                    object
# Pendency                                 object
# Monthly turn over of merchant            object
# Loan Amount Requested                     Int64
# Sanctioned Amount                       float64
# PF Charges                               object
# Doc Charges                              object
# Insurance Charges                        object
# Net Disbursed Amount                     object
# Interest Rate                            object
# Interest Rate Type                       object
# Tenure                                   object
# Repayment Frequency                      object
# Offered Date                     datetime64[ns]
# Disbursed Date                   datetime64[ns]
# Post Sanctioned Status                   object
# Rejected Reason                          object
# Final Status                             object
# Approved Amount                         float64
# Offered Amount                          float64
# Sanction Date                    datetime64[ns]
# Sanction Amount                         float64
# lead_time                                object
# dtype: object

# %%
df_Indifi_final = df_Indifi_final.sort_values(by=['Contact No.','Lead Created Date','lead_time'],ascending=[False,False,False])

# %%
df_Final = df_Final.append(df_Indifi_final)

# %%
path = os.getcwd()

# %%
path
# Out:
# 'C:\\Users\\Tithi Hunka\\OneDrive - Pine Labs Private Limited\\TermLoans Code_Dummy'

# %%
df_Final.to_excel(path+'\\Output\\Consolidated(LK_FL_Indifi)'+ T+'.xlsx',index=False)
